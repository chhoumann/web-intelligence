# %% [markdown]
# # Self Study 3

# %% [markdown]
# This self study concludes our first "miniproject" on crawling and search. The tasks for this self study are:
# - modify/extend the inverted index you constructed in the previous self study to contain for all postings the term frequencies (if your documents are just the titles of the web pages, you will see very few term frequencies larger than 1, but do not worry about that).
# - calculate the idf values for all terms, and also include them in your index (cf. slide 3.20 for a schematic view)
# - implement ranked retrieval as described on slides 3.19 and 3.20 for the ntc.bnc similarity metric

# %%
import requests
from bs4 import BeautifulSoup
from crawler import crawl

# %%
import logging

logging.basicConfig(
    level=logging.ERROR, 
    format='%(asctime)s (%(name)s) %(levelname)s: %(message)s', 
    datefmt='%Y-%m-%d %H:%M:%S'
)

# %%
[visited, _, _] = crawl(["https://notes.bagerbach.com"], timeout=2, host_blacklist=[])
[x for i, x in enumerate(visited.items()) if i < 5]
# Out:
# /home/christian/.local/lib/python3.10/site-packages/bs4/builder/__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:699, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698 # Make the request on the httplib connection object.
# --> 699 httplib_response = self._make_request(
#     700     conn,
#     701     method,
#     702     url,
#     703     timeout=timeout_obj,
#     704     body=body,
#     705     headers=headers,
#     706     chunked=chunked,
#     707 )
#     709 # If we're going to release the connection in ``finally:``, then
#     710 # the response doesn't need to know about the connection. Otherwise
#     711 # it will also try to release it and we'll have a double-release
#     712 # mess.
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:382, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381 try:
# --> 382     self._validate_conn(conn)
#     383 except (SocketTimeout, BaseSSLError) as e:
#     384     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:1012, in HTTPSConnectionPool._validate_conn(self, conn)
#    1011 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1012     conn.connect()
#    1014 if not conn.is_verified:
#
# File /usr/lib/python3/dist-packages/urllib3/connection.py:411, in HTTPSConnection.connect(self)
#     409     context.load_default_certs()
# --> 411 self.sock = ssl_wrap_socket(
#     412     sock=conn,
#     413     keyfile=self.key_file,
#     414     certfile=self.cert_file,
#     415     key_password=self.key_password,
#     416     ca_certs=self.ca_certs,
#     417     ca_cert_dir=self.ca_cert_dir,
#     418     ca_cert_data=self.ca_cert_data,
#     419     server_hostname=server_hostname,
#     420     ssl_context=context,
#     421     tls_in_tls=tls_in_tls,
#     422 )
#     424 # If we're using all defaults and the connection
#     425 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     426 # for the host.
#
# File /usr/lib/python3/dist-packages/urllib3/util/ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#
# File /usr/lib/python3/dist-packages/urllib3/util/ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#
# File /usr/lib/python3.10/ssl.py:513, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     507 def wrap_socket(self, sock, server_side=False,
#     508                 do_handshake_on_connect=True,
#     509                 suppress_ragged_eofs=True,
#     510                 server_hostname=None, session=None):
#     511     # SSLSocket class handles server_hostname encoding before it calls
#     512     # ctx._wrap_socket()
# --> 513     return self.sslsocket_class._create(
#     514         sock=sock,
#     515         server_side=server_side,
#     516         do_handshake_on_connect=do_handshake_on_connect,
#     517         suppress_ragged_eofs=suppress_ragged_eofs,
#     518         server_hostname=server_hostname,
#     519         context=self,
#     520         session=session
#     521     )
#
# File /usr/lib/python3.10/ssl.py:1071, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1070             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1071         self.do_handshake()
#    1072 except (OSError, ValueError):
#
# File /usr/lib/python3.10/ssl.py:1342, in SSLSocket.do_handshake(self, block)
#    1341         self.settimeout(None)
# -> 1342     self._sslobj.do_handshake()
#    1343 finally:
#
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:997)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:755, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     753     e = ProtocolError("Connection aborted.", e)
# --> 755 retries = retries.increment(
#     756     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     757 )
#     758 retries.sleep()
#
# File /usr/lib/python3/dist-packages/urllib3/util/retry.py:574, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     573 if new_retry.is_exhausted():
# --> 574     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     576 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='rch.ac.ir', port=443): Max retries exceeded with url: /article/Details/7731 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:997)')))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# /home/christian/projects/web-intelligence/Self Study 3/selfstudy-E22-03.ipynb Cell 5 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/christian/projects/web-intelligence/Self%20Study%203/selfstudy-E22-03.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> [visited, _, _] = crawl(["https://notes.bagerbach.com"], timeout=2, host_blacklist=[])
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/christian/projects/web-intelligence/Self%20Study%203/selfstudy-E22-03.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> [x for i, x in enumerate(visited.items()) if i < 5]
#
# File ~/projects/web-intelligence/Self Study 3/crawler.py:152, in crawl(seed_urls, host_blacklist, timeout)
#     149     continue
#     151 logging.info(f"Visiting {target_url}")
# --> 152 page = __get_page(target_url)
#     153 if page is None:
#     154     continue
#
# File ~/projects/web-intelligence/Self Study 3/crawler.py:28, in __get_page(url, timeout)
#      24 def __get_page(url: str, timeout=1000) -> BeautifulSoup:
#      25     """
#      26     Get parsed page.
#      27     """
# ---> 28     res = requests.get(url, timeout=timeout)
#      29     __visited_host(__get_host(url))
#      31     return BeautifulSoup(res.text, "html.parser")
#
# File ~/.local/lib/python3.10/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/.local/lib/python3.10/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/.local/lib/python3.10/site-packages/requests/adapters.py:563, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     559         raise ProxyError(e, request=request)
#     561     if isinstance(e.reason, _SSLError):
#     562         # This branch is for urllib3 v1.22 and later.
# --> 563         raise SSLError(e, request=request)
#     565     raise ConnectionError(e, request=request)
#     567 except ClosedPoolError as e:
#
# SSLError: HTTPSConnectionPool(host='rch.ac.ir', port=443): Max retries exceeded with url: /article/Details/7731 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:997)')))

# %%
import nltk
nltk.download('punkt')

# %%
from typing import Dict, List
from nltk.stem.porter import PorterStemmer

vocabulary: Dict[str, List] = {}
stemmer = PorterStemmer()

for url, title in visited.items():
    for pos, token in enumerate(nltk.word_tokenize(title)):
        stemmed = stemmer.stem(token)
        if stemmed not in vocabulary:
            vocabulary[stemmed] = []
        vocabulary[stemmed].append((pos, url))
        
# Vocabulary is a dictionary of tokens and their positions in the titles.
# So the variable is a dict whose keys make up the vocabulary. It isn't exactly a vocabulary. More like an inverted index.
vocabulary

# %%
# Calculate term frequency
inverted_index = vocabulary

for key in inverted_index:
    postings = inverted_index[key]
    inverted_index[key] = {
        "postings": postings,
        "frequency": len(postings),
    }

inverted_index
# Out:
# {'home': {'postings': [(0, 'https://notes.bagerbach.com'),
#    (2, 'https://www.wikiwand.com/')],
#   'frequency': 2},
#  '|': {'postings': [(1, 'https://notes.bagerbach.com'),
#    (1, 'https://bagerbach.com/books'),
#    (3, 'https://notes.bagerbach.com/the-barbell-strategy'),
#    (9, 'https://bagerbach.com/books/the-go-giver'),
#    (18, 'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it'),
#    (8, 'https://notes.bagerbach.com/pp-6-declaring-types-and-type-classes'),
#    (12, 'https://bagerbach.com/books/a-brief-history-of-time'),
#    (2, 'https://notes.bagerbach.com/innovation-multiplier'),
#    (7,
#     'https://notes.bagerbach.com/increase-your-leverage-to-become-more-productive'),
#    (13, 'https://bagerbach.com/books/the-richest-man-in-babylon'),
#    (2, 'https://notes.bagerbach.com/zero-sum'),
#    (3, 'https://notes.bagerbach.com/gall-s-law'),
#    (8,
#     'https://notes.bagerbach.com/minimize-time-getting-into-position-just-go'),
#    (10, 'https://bagerbach.com/books/the-personal-mba'),
#    (4, 'https://notes.bagerbach.com/signal-vs-noise'),
#    (3, 'https://notes.bagerbach.com/the-diderot-effect'),
#    (3, 'https://notes.bagerbach.com/the-pratfall-effect'),
#    (13, 'https://bagerbach.com/books/reality-is-not-what-it-seems'),
#    (4, 'https://notes.bagerbach.com/the-law-of-inertia'),
#    (10, 'https://bagerbach.com/books/leaders-eat-last'),
#    (2, 'https://notes.bagerbach.com/opportunity-cost'),
#    (10, 'https://bagerbach.com/books/anything-you-want'),
#    (1, 'https://notes.bagerbach.com/antifragile'),
#    (2, 'https://notes.bagerbach.com/black-swan')],
#   'frequency': 24},
#  'christian': {'postings': [(2, 'https://notes.bagerbach.com'),
#    (2, 'https://bagerbach.com/books'),
#    (4, 'https://notes.bagerbach.com/the-barbell-strategy'),
#    (10, 'https://bagerbach.com/books/the-go-giver'),
#    (19, 'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it'),
#    (9, 'https://notes.bagerbach.com/pp-6-declaring-types-and-type-classes'),
#    (13, 'https://bagerbach.com/books/a-brief-history-of-time'),
#    (3, 'https://notes.bagerbach.com/innovation-multiplier'),
#    (8,
#     'https://notes.bagerbach.com/increase-your-leverage-to-become-more-productive'),
#    (14, 'https://bagerbach.com/books/the-richest-man-in-babylon'),
#    (3, 'https://notes.bagerbach.com/zero-sum'),
#    (4, 'https://notes.bagerbach.com/gall-s-law'),
#    (9,
#     'https://notes.bagerbach.com/minimize-time-getting-into-position-just-go'),
#    (11, 'https://bagerbach.com/books/the-personal-mba'),
#    (5, 'https://notes.bagerbach.com/signal-vs-noise'),
#    (4, 'https://notes.bagerbach.com/the-diderot-effect'),
#    (4, 'https://notes.bagerbach.com/the-pratfall-effect'),
#    (14, 'https://bagerbach.com/books/reality-is-not-what-it-seems'),
#    (5, 'https://notes.bagerbach.com/the-law-of-inertia'),
#    (11, 'https://bagerbach.com/books/leaders-eat-last'),
#    (3, 'https://notes.bagerbach.com/opportunity-cost'),
#    (11, 'https://bagerbach.com/books/anything-you-want'),
#    (2, 'https://notes.bagerbach.com/antifragile'),
#    (3, 'https://notes.bagerbach.com/black-swan')],
#   'frequency': 24},
#  "'s": {'postings': [(3, 'https://notes.bagerbach.com'),
#    (5, 'https://notes.bagerbach.com/the-barbell-strategy'),
#    (10, 'https://notes.bagerbach.com/pp-6-declaring-types-and-type-classes'),
#    (4, 'https://notes.bagerbach.com/innovation-multiplier'),
#    (1,
#     'https://templatecount.toolforge.org/index.php?lang=en&namespace=0&name=Antifragile'),
#    (9,
#     'https://notes.bagerbach.com/increase-your-leverage-to-become-more-productive'),
#    (4, 'https://notes.bagerbach.com/zero-sum'),
#    (1, 'https://notes.bagerbach.com/gall-s-law'),
#    (5, 'https://notes.bagerbach.com/gall-s-law'),
#    (10,
#     'https://notes.bagerbach.com/minimize-time-getting-into-position-just-go'),
#    (6, 'https://notes.bagerbach.com/signal-vs-noise'),
#    (5, 'https://notes.bagerbach.com/the-diderot-effect'),
#    (5, 'https://notes.bagerbach.com/the-pratfall-effect'),
#    (6, 'https://notes.bagerbach.com/the-law-of-inertia'),
#    (4, 'https://notes.bagerbach.com/opportunity-cost'),
#    (3, 'https://notes.bagerbach.com/antifragile'),
#    (4, 'https://notes.bagerbach.com/black-swan')],
#   'frequency': 17},
#  'note': {'postings': [(4, 'https://notes.bagerbach.com'),
#    (6, 'https://notes.bagerbach.com/the-barbell-strategy'),
#    (8, 'https://bagerbach.com/books/the-go-giver'),
#    (17, 'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it'),
#    (11, 'https://notes.bagerbach.com/pp-6-declaring-types-and-type-classes'),
#    (11, 'https://bagerbach.com/books/a-brief-history-of-time'),
#    (5, 'https://notes.bagerbach.com/innovation-multiplier'),
#    (10,
#     'https://notes.bagerbach.com/increase-your-leverage-to-become-more-productive'),
#    (12, 'https://bagerbach.com/books/the-richest-man-in-babylon'),
#    (5, 'https://notes.bagerbach.com/zero-sum'),
#    (6, 'https://notes.bagerbach.com/gall-s-law'),
#    (11,
#     'https://notes.bagerbach.com/minimize-time-getting-into-position-just-go'),
#    (9, 'https://bagerbach.com/books/the-personal-mba'),
#    (7, 'https://notes.bagerbach.com/signal-vs-noise'),
#    (6, 'https://notes.bagerbach.com/the-diderot-effect'),
#    (6, 'https://notes.bagerbach.com/the-pratfall-effect'),
#    (12, 'https://bagerbach.com/books/reality-is-not-what-it-seems'),
#    (7, 'https://notes.bagerbach.com/the-law-of-inertia'),
#    (9, 'https://bagerbach.com/books/leaders-eat-last'),
#    (5, 'https://notes.bagerbach.com/opportunity-cost'),
#    (9, 'https://bagerbach.com/books/anything-you-want'),
#    (4, 'https://notes.bagerbach.com/antifragile'),
#    (5, 'https://notes.bagerbach.com/black-swan')],
#   'frequency': 23},
#  'book': {'postings': [(0, 'https://bagerbach.com/books')], 'frequency': 1},
#  'b': {'postings': [(3, 'https://bagerbach.com/books'),
#    (11, 'https://bagerbach.com/books/the-go-giver'),
#    (20, 'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it'),
#    (14, 'https://bagerbach.com/books/a-brief-history-of-time'),
#    (15, 'https://bagerbach.com/books/the-richest-man-in-babylon'),
#    (12, 'https://bagerbach.com/books/the-personal-mba'),
#    (15, 'https://bagerbach.com/books/reality-is-not-what-it-seems'),
#    (12, 'https://bagerbach.com/books/leaders-eat-last'),
#    (12, 'https://bagerbach.com/books/anything-you-want')],
#   'frequency': 9},
#  '.': {'postings': [(4, 'https://bagerbach.com/books'),
#    (12, 'https://bagerbach.com/books/the-go-giver'),
#    (21, 'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it'),
#    (15, 'https://bagerbach.com/books/a-brief-history-of-time'),
#    (16, 'https://bagerbach.com/books/the-richest-man-in-babylon'),
#    (13, 'https://bagerbach.com/books/the-personal-mba'),
#    (2, 'https://notes.bagerbach.com/signal-vs-noise'),
#    (16, 'https://bagerbach.com/books/reality-is-not-what-it-seems'),
#    (13, 'https://bagerbach.com/books/leaders-eat-last'),
#    (13, 'https://bagerbach.com/books/anything-you-want')],
#   'frequency': 10},
#  'b.': {'postings': [(5, 'https://bagerbach.com/books'),
#    (13, 'https://bagerbach.com/books/the-go-giver'),
#    (22, 'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it'),
#    (16, 'https://bagerbach.com/books/a-brief-history-of-time'),
#    (17, 'https://bagerbach.com/books/the-richest-man-in-babylon'),
#    (14, 'https://bagerbach.com/books/the-personal-mba'),
#    (17, 'https://bagerbach.com/books/reality-is-not-what-it-seems'),
#    (14, 'https://bagerbach.com/books/leaders-eat-last'),
#    (14, 'https://bagerbach.com/books/anything-you-want')],
#   'frequency': 9},
#  'houmann': {'postings': [(6, 'https://bagerbach.com/books'),
#    (14, 'https://bagerbach.com/books/the-go-giver'),
#    (23, 'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it'),
#    (17, 'https://bagerbach.com/books/a-brief-history-of-time'),
#    (18, 'https://bagerbach.com/books/the-richest-man-in-babylon'),
#    (15, 'https://bagerbach.com/books/the-personal-mba'),
#    (18, 'https://bagerbach.com/books/reality-is-not-what-it-seems'),
#    (15, 'https://bagerbach.com/books/leaders-eat-last'),
#    (15, 'https://bagerbach.com/books/anything-you-want')],
#   'frequency': 9},
#  'the': {'postings': [(0, 'https://notes.bagerbach.com/the-barbell-strategy'),
#    (0, 'https://bagerbach.com/books/the-go-giver'),
#    (0, 'https://bagerbach.com/books/the-richest-man-in-babylon'),
#    (4, 'https://www.thefwa.com/interview/team-at-wikiwand/'),
#    (0, 'https://bagerbach.com/books/the-personal-mba'),
#    (0, 'https://notes.bagerbach.com/the-diderot-effect'),
#    (0, 'https://notes.bagerbach.com/the-pratfall-effect'),
#    (0, 'https://notes.bagerbach.com/the-law-of-inertia')],
#   'frequency': 8},
#  'barbel': {'postings': [(1,
#     'https://notes.bagerbach.com/the-barbell-strategy')],
#   'frequency': 1},
#  'strategi': {'postings': [(2,
#     'https://notes.bagerbach.com/the-barbell-strategy')],
#   'frequency': 1},
#  'go-giv': {'postings': [(1, 'https://bagerbach.com/books/the-go-giver')],
#   'frequency': 1},
#  'by': {'postings': [(2, 'https://bagerbach.com/books/the-go-giver'),
#    (11, 'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it'),
#    (5, 'https://bagerbach.com/books/a-brief-history-of-time'),
#    (5, 'https://bagerbach.com/books/the-richest-man-in-babylon'),
#    (3, 'https://bagerbach.com/books/the-personal-mba'),
#    (6, 'https://bagerbach.com/books/reality-is-not-what-it-seems'),
#    (3, 'https://bagerbach.com/books/leaders-eat-last'),
#    (3, 'https://bagerbach.com/books/anything-you-want')],
#   'frequency': 8},
#  'bob': {'postings': [(3, 'https://bagerbach.com/books/the-go-giver')],
#   'frequency': 1},
#  'burg': {'postings': [(4, 'https://bagerbach.com/books/the-go-giver')],
#   'frequency': 1},
#  '-': {'postings': [(5, 'https://bagerbach.com/books/the-go-giver'),
#    (1, 'https://www.wikiwand.com/en/Antifragile#/Barbell_strategy'),
#    (14, 'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it'),
#    (2, 'https://notes.bagerbach.com/pp-6-declaring-types-and-type-classes'),
#    (2, 'https://www.wikiwand.com/privacy'),
#    (7,
#     'https://en.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0'),
#    (7,
#     'https://en.m.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0&mobileaction=toggle_view_mobile'),
#    (8, 'https://bagerbach.com/books/a-brief-history-of-time'),
#    (7, 'https://en.wikipedia.org/wiki/Special:WhatLinksHere/Antifragile'),
#    (1, 'https://www.wikiwand.com/contact'),
#    (4,
#     'https://chrome.google.com/webstore/detail/wikiwand-wikipedia-modern/emffkefkbkpkgpdeeooapgaicgmcbolj'),
#    (4,
#     'https://templatecount.toolforge.org/index.php?lang=en&namespace=0&name=Antifragile'),
#    (1, 'https://www.wikiwand.com/'),
#    (9, 'https://bagerbach.com/books/the-richest-man-in-babylon'),
#    (4,
#     'https://en.wikipedia.org/w/index.php?title=Talk:Antifragile&action=edit'),
#    (5, 'https://developer.wikimedia.org'),
#    (1, 'https://www.wikiwand.com/press'),
#    (3, 'https://www.thefwa.com/interview/team-at-wikiwand/'),
#    (6,
#     'https://en.wikipedia.org/wiki/Wikipedia:Disambiguation_pages_with_links'),
#    (4, 'https://www.wikiwand.com/en/File:Disambig_gray.svg'),
#    (7,
#     'https://en.m.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0&limit=100'),
#    (10,
#     'https://da.wikipedia.org/wiki/Wikipedia:Artikler_med_flertydige_titler_som_der_henvises_til'),
#    (4, 'https://en.wikipedia.org/wiki/File:Red_star2.png'),
#    (6, 'https://bagerbach.com/books/the-personal-mba'),
#    (7, 'https://da.wikipedia.org/wiki/Speciel:Hvad_linker_hertil/B%C3%A5nd'),
#    (5, 'https://en.wikipedia.org/wiki/File:Rotating_red_star.gif'),
#    (3, 'https://www.wikiwand.com/en/Scalable_Vector_Graphics'),
#    (2, 'https://en.wikipedia.org/wiki/Lee_Jenkins'),
#    (3, 'https://da.wikipedia.org/wiki/Hj%C3%A6lp:Forside'),
#    (3,
#     'https://en.m.wikipedia.org/w/index.php?title=Alan_Blinder&action=edit'),
#    (4, 'https://en.wikipedia.org/wiki/User_talk:Vegaswikian'),
#    (1, 'https://da.wikipedia.org/wiki/Frekvensb%C3%A5nd'),
#    (3, 'https://min.wikipedia.org/wiki/Bantuan:Isi'),
#    (5,
#     'https://en.m.wikipedia.org/w/index.php?title=Antifragile_(disambiguation)&action=edit'),
#    (7,
#     'https://en.wikipedia.org/wiki/Wikipedia:Disambiguation_pages_with_links/February_2019'),
#    (7,
#     'https://da.wikipedia.org/w/index.php?title=Speciel:Hvad_linker_hertil/B%C3%A5nd&limit=500'),
#    (3, 'https://bi.wikipedia.org/wiki/Help:Contents'),
#    (9, 'https://bagerbach.com/books/reality-is-not-what-it-seems'),
#    (3,
#     'https://km.wikipedia.org/wiki/%E1%9E%87%E1%9F%86%E1%9E%93%E1%9E%BD%E1%9E%99:%E1%9E%98%E1%9E%B6%E1%9E%8F%E1%9E%B7%E1%9E%80%E1%9E%B6'),
#    (1, 'https://en.wikipedia.org/wiki/Anuradha'),
#    (6,
#     'https://en.m.wikipedia.org/w/index.php?title=Module:Yesno&action=edit'),
#    (2, 'https://da.wikipedia.org/wiki/Speciel:For%C3%A6ldrel%C3%B8se_sider'),
#    (3, 'https://bat-smg.wikipedia.org/wiki/Pagelba:Tor%C4%97n%C4%ABs'),
#    (6, 'https://bagerbach.com/books/leaders-eat-last'),
#    (2, 'https://en.wikipedia.org/wiki/Charles_Taylor'),
#    (3, 'https://als.wikipedia.org/wiki/Wikipedia:Hilfe'),
#    (6, 'https://sw.wikipedia.org/wiki/Wikipedia:Msaada_wa_kuanzisha_makala'),
#    (4, 'https://da.wikipedia.org/wiki/Virkning_(flertydig)'),
#    (1, 'https://en.wikipedia.org/wiki/Deputy'),
#    (6, 'https://bagerbach.com/books/anything-you-want'),
#    (4, 'https://en.m.wikipedia.org/wiki/Module:Category_handler/blacklist'),
#    (3,
#     'https://kn.wikipedia.org/wiki/%E0%B2%B8%E0%B2%B9%E0%B2%BE%E0%B2%AF:%E0%B2%AA%E0%B2%B0%E0%B2%BF%E0%B2%B5%E0%B2%BF%E0%B2%A1%E0%B2%BF'),
#    (5,
#     'https://commons.wikimedia.org/wiki/Template:Vector_version_available/sco'),
#    (1, 'https://en.wikipedia.org/wiki/CSO'),
#    (1, 'https://da.wikipedia.org/wiki/Kup'),
#    (1, 'https://www.wikidata.org/wiki/Special:EntityPage/Q16355515'),
#    (3, 'https://ang.wikipedia.org/wiki/Help:Inno%C3%BE'),
#    (4, 'https://ceb.wikipedia.org/wiki/Tabang:Mga_sulod'),
#    (2, 'https://en.wikipedia.org/wiki/Deputy_mayor'),
#    (3, 'https://da.wikipedia.org/wiki/Hj%C3%A6lp:Mentorer'),
#    (5, 'https://als.wikipedia.org/wiki/Spezial:Myyni_Byytreeg'),
#    (1,
#     'https://ang.wikipedia.org/w/index.php?title=Syndrig:Book&bookcmd=book_creator&referer=Help%3AInno%C3%BE'),
#    (8,
#     'https://sw.wikipedia.org/wiki/Majadiliano_ya_Wikipedia:Msaada_wa_kuanzisha_makala'),
#    (1, 'https://en.wikipedia.org/wiki/Chamoy'),
#    (2, 'https://da.wikipedia.org/wiki/Wayback_Machine')],
#   'frequency': 65},
#  'summari': {'postings': [(6, 'https://bagerbach.com/books/the-go-giver'),
#    (15, 'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it'),
#    (9, 'https://bagerbach.com/books/a-brief-history-of-time'),
#    (10, 'https://bagerbach.com/books/the-richest-man-in-babylon'),
#    (7, 'https://bagerbach.com/books/the-personal-mba'),
#    (10, 'https://bagerbach.com/books/reality-is-not-what-it-seems'),
#    (7, 'https://bagerbach.com/books/leaders-eat-last'),
#    (7, 'https://bagerbach.com/books/anything-you-want')],
#   'frequency': 8},
#  '&': {'postings': [(7, 'https://bagerbach.com/books/the-go-giver'),
#    (16, 'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it'),
#    (10, 'https://bagerbach.com/books/a-brief-history-of-time'),
#    (11, 'https://bagerbach.com/books/the-richest-man-in-babylon'),
#    (8, 'https://bagerbach.com/books/the-personal-mba'),
#    (11, 'https://bagerbach.com/books/reality-is-not-what-it-seems'),
#    (8, 'https://bagerbach.com/books/leaders-eat-last'),
#    (8, 'https://bagerbach.com/books/anything-you-want')],
#   'frequency': 8},
#  'antifragil': {'postings': [(0,
#     'https://www.wikiwand.com/en/Antifragile#/Barbell_strategy'),
#    (5,
#     'https://en.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0'),
#    (5,
#     'https://en.m.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0&mobileaction=toggle_view_mobile'),
#    (5, 'https://en.wikipedia.org/wiki/Special:WhatLinksHere/Antifragile'),
#    (3,
#     'https://en.wikipedia.org/w/index.php?title=Talk:Antifragile&action=edit'),
#    (5,
#     'https://en.m.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0&limit=100'),
#    (1,
#     'https://en.m.wikipedia.org/w/index.php?title=Antifragile_(disambiguation)&action=edit'),
#    (0, 'https://notes.bagerbach.com/antifragile')],
#   'frequency': 8},
#  'wikiwand': {'postings': [(2,
#     'https://www.wikiwand.com/en/Antifragile#/Barbell_strategy'),
#    (3, 'https://www.wikiwand.com/privacy'),
#    (0, 'https://www.wikiwand.com/contact'),
#    (0,
#     'https://chrome.google.com/webstore/detail/wikiwand-wikipedia-modern/emffkefkbkpkgpdeeooapgaicgmcbolj'),
#    (0, 'https://www.wikiwand.com/'),
#    (0, 'https://www.wikiwand.com/press'),
#    (2, 'https://techcrunch.com/2014/08/07/wikiwand/'),
#    (2, 'https://www.thefwa.com/interview/team-at-wikiwand/'),
#    (5, 'https://www.wikiwand.com/en/File:Disambig_gray.svg'),
#    (0, 'https://www.facebook.com/wikiwandapp'),
#    (4, 'https://www.wikiwand.com/en/Scalable_Vector_Graphics')],
#   'frequency': 11},
#  'whi': {'postings': [(0,
#     'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it')],
#   'frequency': 1},
#  'we': {'postings': [(1,
#     'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it')],
#   'frequency': 1},
#  'get': {'postings': [(2,
#     'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it'),
#    (2,
#     'https://notes.bagerbach.com/minimize-time-getting-into-position-just-go')],
#   'frequency': 2},
#  'fat': {'postings': [(3,
#     'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it')],
#   'frequency': 1},
#  ':': {'postings': [(4,
#     'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it'),
#    (1,
#     'https://chrome.google.com/webstore/detail/wikiwand-wikipedia-modern/emffkefkbkpkgpdeeooapgaicgmcbolj'),
#    (2,
#     'https://en.wikipedia.org/w/index.php?title=Talk:Antifragile&action=edit'),
#    (1,
#     'https://en.wikipedia.org/wiki/Wikipedia:Disambiguation_pages_with_links'),
#    (1, 'https://www.wikiwand.com/en/File:Disambig_gray.svg'),
#    (1,
#     'https://da.wikipedia.org/wiki/Wikipedia:Artikler_med_flertydige_titler_som_der_henvises_til'),
#    (1, 'https://en.wikipedia.org/wiki/File:Red_star2.png'),
#    (1, 'https://en.wikipedia.org/wiki/File:Rotating_red_star.gif'),
#    (1,
#     'https://lv.wikipedia.org/wiki/Vikiprojekts:Vikip%C4%93dijas_uzlabo%C5%A1ana/Noz%C4%ABmju_atdal%C4%AB%C5%A1ana/Noz%C4%ABmju_atdal%C4%AB%C5%A1anas_lapas_ar_sait%C4%93m'),
#    (1, 'https://da.wikipedia.org/wiki/Hj%C3%A6lp:Forside'),
#    (2, 'https://en.wikipedia.org/wiki/User_talk:Vegaswikian'),
#    (1, 'https://min.wikipedia.org/wiki/Bantuan:Isi'),
#    (1,
#     'https://en.wikipedia.org/wiki/Wikipedia:Disambiguation_pages_with_links/February_2019'),
#    (1,
#     'https://kk.wikipedia.org/wiki/%D0%A3%D0%B8%D0%BA%D0%B8%D0%BF%D0%B5%D0%B4%D0%B8%D1%8F:%D0%90%D0%BD%D1%8B%D2%9B%D1%82%D0%B0%D0%BC%D0%B0'),
#    (1, 'https://bi.wikipedia.org/wiki/Help:Contents'),
#    (1,
#     'https://km.wikipedia.org/wiki/%E1%9E%87%E1%9F%86%E1%9E%93%E1%9E%BD%E1%9E%99:%E1%9E%98%E1%9E%B6%E1%9E%8F%E1%9E%B7%E1%9E%80%E1%9E%B6'),
#    (4,
#     'https://en.m.wikipedia.org/w/index.php?title=Module:Yesno&action=edit'),
#    (1, 'https://bat-smg.wikipedia.org/wiki/Pagelba:Tor%C4%97n%C4%ABs'),
#    (1, 'https://als.wikipedia.org/wiki/Wikipedia:Hilfe'),
#    (1, 'https://sw.wikipedia.org/wiki/Wikipedia:Msaada_wa_kuanzisha_makala'),
#    (1,
#     'https://mn.wikipedia.org/wiki/%D0%A2%D1%83%D1%81%D0%BB%D0%B0%D0%BC%D0%B6:%D0%90%D0%B3%D1%83%D1%83%D0%BB%D0%B3%D0%B0'),
#    (1, 'https://en.m.wikipedia.org/wiki/Module:Category_handler/blacklist'),
#    (1,
#     'https://kn.wikipedia.org/wiki/%E0%B2%B8%E0%B2%B9%E0%B2%BE%E0%B2%AF:%E0%B2%AA%E0%B2%B0%E0%B2%BF%E0%B2%B5%E0%B2%BF%E0%B2%A1%E0%B2%BF'),
#    (1,
#     'https://commons.wikimedia.org/wiki/Template:Vector_version_available/sco'),
#    (1, 'https://ang.wikipedia.org/wiki/Help:Inno%C3%BE'),
#    (2,
#     'https://kk.wikipedia.org/w/index.php?title=%D0%A3%D0%B8%D0%BA%D0%B8%D0%BF%D0%B5%D0%B4%D0%B8%D1%8F:%D0%90%D0%BD%D1%8B%D2%9B%D1%82%D0%B0%D0%BC%D0%B0&action=info'),
#    (1, 'https://ceb.wikipedia.org/wiki/Tabang:Mga_sulod'),
#    (1, 'https://da.wikipedia.org/wiki/Hj%C3%A6lp:Mentorer'),
#    (1,
#     'https://tt.wikipedia.org/wiki/%D0%92%D0%B8%D0%BA%D0%B8%D0%BF%D0%B5%D0%B4%D0%B8%D1%8F:%D0%AF%D1%80%D0%B4%D3%99%D0%BC'),
#    (3,
#     'https://sw.wikipedia.org/wiki/Majadiliano_ya_Wikipedia:Msaada_wa_kuanzisha_makala')],
#   'frequency': 30},
#  'and': {'postings': [(5,
#     'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it'),
#    (5, 'https://notes.bagerbach.com/pp-6-declaring-types-and-type-classes'),
#    (1, 'https://developer.wikimedia.org'),
#    (2,
#     'https://web.archive.org/web/20030401130935/http://topology.org/comms/radcodes.html')],
#   'frequency': 4},
#  'what': {'postings': [(6,
#     'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it'),
#    (3, 'https://bagerbach.com/books/reality-is-not-what-it-seems')],
#   'frequency': 2},
#  'to': {'postings': [(7,
#     'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it'),
#    (3,
#     'https://en.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0'),
#    (3,
#     'https://en.m.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0&mobileaction=toggle_view_mobile'),
#    (3, 'https://en.wikipedia.org/wiki/Special:WhatLinksHere/Antifragile'),
#    (3,
#     'https://notes.bagerbach.com/increase-your-leverage-to-become-more-productive'),
#    (6, 'https://techcrunch.com/2014/08/07/wikiwand/'),
#    (3,
#     'https://en.m.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0&limit=100')],
#   'frequency': 7},
#  'do': {'postings': [(8,
#     'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it')],
#   'frequency': 1},
#  'about': {'postings': [(9,
#     'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it')],
#   'frequency': 1},
#  'it': {'postings': [(10,
#     'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it'),
#    (4, 'https://bagerbach.com/books/reality-is-not-what-it-seems')],
#   'frequency': 2},
#  'gari': {'postings': [(12,
#     'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it')],
#   'frequency': 1},
#  'taub': {'postings': [(13,
#     'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it')],
#   'frequency': 1},
#  'pp': {'postings': [(0,
#     'https://notes.bagerbach.com/pp-6-declaring-types-and-type-classes')],
#   'frequency': 1},
#  '6': {'postings': [(1,
#     'https://notes.bagerbach.com/pp-6-declaring-types-and-type-classes')],
#   'frequency': 1},
#  'declar': {'postings': [(3,
#     'https://notes.bagerbach.com/pp-6-declaring-types-and-type-classes')],
#   'frequency': 1},
#  'type': {'postings': [(4,
#     'https://notes.bagerbach.com/pp-6-declaring-types-and-type-classes'),
#    (6, 'https://notes.bagerbach.com/pp-6-declaring-types-and-type-classes')],
#   'frequency': 2},
#  'class': {'postings': [(7,
#     'https://notes.bagerbach.com/pp-6-declaring-types-and-type-classes')],
#   'frequency': 1},
#  'privaci': {'postings': [(0, 'https://www.wikiwand.com/privacy')],
#   'frequency': 1},
#  'polici': {'postings': [(1, 'https://www.wikiwand.com/privacy')],
#   'frequency': 1},
#  'page': {'postings': [(0,
#     'https://en.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0'),
#    (0,
#     'https://en.m.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0&mobileaction=toggle_view_mobile'),
#    (0, 'https://en.wikipedia.org/wiki/Special:WhatLinksHere/Antifragile'),
#    (3,
#     'https://en.wikipedia.org/wiki/Wikipedia:Disambiguation_pages_with_links'),
#    (0,
#     'https://en.m.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0&limit=100'),
#    (3,
#     'https://en.wikipedia.org/wiki/Wikipedia:Disambiguation_pages_with_links/February_2019')],
#   'frequency': 6},
#  'that': {'postings': [(1,
#     'https://en.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0'),
#    (1,
#     'https://en.m.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0&mobileaction=toggle_view_mobile'),
#    (1, 'https://en.wikipedia.org/wiki/Special:WhatLinksHere/Antifragile'),
#    (1,
#     'https://en.m.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0&limit=100')],
#   'frequency': 4},
#  'link': {'postings': [(2,
#     'https://en.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0'),
#    (2,
#     'https://en.m.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0&mobileaction=toggle_view_mobile'),
#    (2, 'https://en.wikipedia.org/wiki/Special:WhatLinksHere/Antifragile'),
#    (5,
#     'https://en.wikipedia.org/wiki/Wikipedia:Disambiguation_pages_with_links'),
#    (2,
#     'https://en.m.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0&limit=100')],
#   'frequency': 5},
#  '``': {'postings': [(4,
#     'https://en.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0'),
#    (4,
#     'https://en.m.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0&mobileaction=toggle_view_mobile'),
#    (4, 'https://en.wikipedia.org/wiki/Special:WhatLinksHere/Antifragile'),
#    (4,
#     'https://en.m.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0&limit=100'),
#    (4, 'https://da.wikipedia.org/wiki/Speciel:Hvad_linker_hertil/B%C3%A5nd'),
#    (4,
#     'https://da.wikipedia.org/w/index.php?title=Speciel:Hvad_linker_hertil/B%C3%A5nd&limit=500')],
#   'frequency': 6},
#  "''": {'postings': [(6,
#     'https://en.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0'),
#    (6,
#     'https://en.m.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0&mobileaction=toggle_view_mobile'),
#    (6, 'https://en.wikipedia.org/wiki/Special:WhatLinksHere/Antifragile'),
#    (6,
#     'https://en.m.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0&limit=100'),
#    (6, 'https://da.wikipedia.org/wiki/Speciel:Hvad_linker_hertil/B%C3%A5nd'),
#    (6,
#     'https://da.wikipedia.org/w/index.php?title=Speciel:Hvad_linker_hertil/B%C3%A5nd&limit=500')],
#   'frequency': 6},
#  'wikipedia': {'postings': [(8,
#     'https://en.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0'),
#    (8,
#     'https://en.m.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0&mobileaction=toggle_view_mobile'),
#    (8, 'https://en.wikipedia.org/wiki/Special:WhatLinksHere/Antifragile'),
#    (2,
#     'https://chrome.google.com/webstore/detail/wikiwand-wikipedia-modern/emffkefkbkpkgpdeeooapgaicgmcbolj'),
#    (5,
#     'https://en.wikipedia.org/w/index.php?title=Talk:Antifragile&action=edit'),
#    (8, 'https://techcrunch.com/2014/08/07/wikiwand/'),
#    (0,
#     'https://en.wikipedia.org/wiki/Wikipedia:Disambiguation_pages_with_links'),
#    (7,
#     'https://en.wikipedia.org/wiki/Wikipedia:Disambiguation_pages_with_links'),
#    (8,
#     'https://en.m.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0&limit=100'),
#    (0,
#     'https://da.wikipedia.org/wiki/Wikipedia:Artikler_med_flertydige_titler_som_der_henvises_til'),
#    (11,
#     'https://da.wikipedia.org/wiki/Wikipedia:Artikler_med_flertydige_titler_som_der_henvises_til'),
#    (5, 'https://en.wikipedia.org/wiki/File:Red_star2.png'),
#    (8, 'https://da.wikipedia.org/wiki/Speciel:Hvad_linker_hertil/B%C3%A5nd'),
#    (6, 'https://en.wikipedia.org/wiki/File:Rotating_red_star.gif'),
#    (3, 'https://en.wikipedia.org/wiki/Lee_Jenkins'),
#    (4, 'https://da.wikipedia.org/wiki/Hj%C3%A6lp:Forside'),
#    (4,
#     'https://en.m.wikipedia.org/w/index.php?title=Alan_Blinder&action=edit'),
#    (5, 'https://en.wikipedia.org/wiki/User_talk:Vegaswikian'),
#    (2, 'https://da.wikipedia.org/wiki/Frekvensb%C3%A5nd'),
#    (4, 'https://min.wikipedia.org/wiki/Bantuan:Isi'),
#    (6,
#     'https://en.m.wikipedia.org/w/index.php?title=Antifragile_(disambiguation)&action=edit'),
#    (0,
#     'https://en.wikipedia.org/wiki/Wikipedia:Disambiguation_pages_with_links/February_2019'),
#    (8,
#     'https://en.wikipedia.org/wiki/Wikipedia:Disambiguation_pages_with_links/February_2019'),
#    (8,
#     'https://da.wikipedia.org/w/index.php?title=Speciel:Hvad_linker_hertil/B%C3%A5nd&limit=500'),
#    (4, 'https://bi.wikipedia.org/wiki/Help:Contents'),
#    (2, 'https://en.wikipedia.org/wiki/Anuradha'),
#    (7,
#     'https://en.m.wikipedia.org/w/index.php?title=Module:Yesno&action=edit'),
#    (3, 'https://da.wikipedia.org/wiki/Speciel:For%C3%A6ldrel%C3%B8se_sider'),
#    (4, 'https://bat-smg.wikipedia.org/wiki/Pagelba:Tor%C4%97n%C4%ABs'),
#    (3, 'https://en.wikipedia.org/wiki/Charles_Taylor'),
#    (0, 'https://als.wikipedia.org/wiki/Wikipedia:Hilfe'),
#    (5, 'https://als.wikipedia.org/wiki/Wikipedia:Hilfe'),
#    (0, 'https://sw.wikipedia.org/wiki/Wikipedia:Msaada_wa_kuanzisha_makala'),
#    (7, 'https://sw.wikipedia.org/wiki/Wikipedia:Msaada_wa_kuanzisha_makala'),
#    (5, 'https://da.wikipedia.org/wiki/Virkning_(flertydig)'),
#    (2, 'https://en.wikipedia.org/wiki/Deputy'),
#    (5, 'https://en.m.wikipedia.org/wiki/Module:Category_handler/blacklist'),
#    (2, 'https://en.wikipedia.org/wiki/CSO'),
#    (2, 'https://da.wikipedia.org/wiki/Kup'),
#    (5, 'https://ceb.wikipedia.org/wiki/Tabang:Mga_sulod'),
#    (3, 'https://en.wikipedia.org/wiki/Deputy_mayor'),
#    (4, 'https://da.wikipedia.org/wiki/Hj%C3%A6lp:Mentorer'),
#    (4,
#     'https://tt.wikipedia.org/wiki/%D0%92%D0%B8%D0%BA%D0%B8%D0%BF%D0%B5%D0%B4%D0%B8%D1%8F:%D0%AF%D1%80%D0%B4%D3%99%D0%BC'),
#    (7, 'https://als.wikipedia.org/wiki/Spezial:Myyni_Byytreeg'),
#    (2,
#     'https://sw.wikipedia.org/wiki/Majadiliano_ya_Wikipedia:Msaada_wa_kuanzisha_makala'),
#    (9,
#     'https://sw.wikipedia.org/wiki/Majadiliano_ya_Wikipedia:Msaada_wa_kuanzisha_makala'),
#    (2, 'https://en.wikipedia.org/wiki/Chamoy'),
#    (3, 'https://da.wikipedia.org/wiki/Wayback_Machine')],
#   'frequency': 48},
#  'a': {'postings': [(0, 'https://bagerbach.com/books/a-brief-history-of-time'),
#    (9, 'https://techcrunch.com/2014/08/07/wikiwand/')],
#   'frequency': 2},
#  'brief': {'postings': [(1,
#     'https://bagerbach.com/books/a-brief-history-of-time')],
#   'frequency': 1},
#  'histori': {'postings': [(2,
#     'https://bagerbach.com/books/a-brief-history-of-time')],
#   'frequency': 1},
#  'of': {'postings': [(3,
#     'https://bagerbach.com/books/a-brief-history-of-time'),
#    (2, 'https://notes.bagerbach.com/the-law-of-inertia')],
#   'frequency': 2},
#  'time': {'postings': [(4,
#     'https://bagerbach.com/books/a-brief-history-of-time'),
#    (1,
#     'https://notes.bagerbach.com/minimize-time-getting-into-position-just-go')],
#   'frequency': 2},
#  'stephen': {'postings': [(6,
#     'https://bagerbach.com/books/a-brief-history-of-time')],
#   'frequency': 1},
#  'hawk': {'postings': [(7,
#     'https://bagerbach.com/books/a-brief-history-of-time')],
#   'frequency': 1},
#  'innov': {'postings': [(0,
#     'https://notes.bagerbach.com/innovation-multiplier')],
#   'frequency': 1},
#  'multipli': {'postings': [(1,
#     'https://notes.bagerbach.com/innovation-multiplier')],
#   'frequency': 1},
#  'contact': {'postings': [(2, 'https://www.wikiwand.com/contact')],
#   'frequency': 1},
#  'us': {'postings': [(3, 'https://www.wikiwand.com/contact')], 'frequency': 1},
#  'modern': {'postings': [(3,
#     'https://chrome.google.com/webstore/detail/wikiwand-wikipedia-modern/emffkefkbkpkgpdeeooapgaicgmcbolj')],
#   'frequency': 1},
#  'chrome': {'postings': [(5,
#     'https://chrome.google.com/webstore/detail/wikiwand-wikipedia-modern/emffkefkbkpkgpdeeooapgaicgmcbolj')],
#   'frequency': 1},
#  'webshop': {'postings': [(6,
#     'https://chrome.google.com/webstore/detail/wikiwand-wikipedia-modern/emffkefkbkpkgpdeeooapgaicgmcbolj')],
#   'frequency': 1},
#  'jarry1250': {'postings': [(0,
#     'https://templatecount.toolforge.org/index.php?lang=en&namespace=0&name=Antifragile')],
#   'frequency': 1},
#  'wikimedia': {'postings': [(2,
#     'https://templatecount.toolforge.org/index.php?lang=en&namespace=0&name=Antifragile'),
#    (3, 'https://developer.wikimedia.org'),
#    (6, 'https://developer.wikimedia.org'),
#    (0, 'https://wikimediafoundation.org/'),
#    (6,
#     'https://commons.wikimedia.org/wiki/Template:Vector_version_available/sco')],
#   'frequency': 5},
#  'laboratori': {'postings': [(3,
#     'https://templatecount.toolforge.org/index.php?lang=en&namespace=0&name=Antifragile')],
#   'frequency': 1},
#  'templat': {'postings': [(5,
#     'https://templatecount.toolforge.org/index.php?lang=en&namespace=0&name=Antifragile'),
#    (0,
#     'https://commons.wikimedia.org/wiki/Template:Vector_version_available/sco')],
#   'frequency': 2},
#  'transclus': {'postings': [(6,
#     'https://templatecount.toolforge.org/index.php?lang=en&namespace=0&name=Antifragile')],
#   'frequency': 1},
#  'count': {'postings': [(7,
#     'https://templatecount.toolforge.org/index.php?lang=en&namespace=0&name=Antifragile')],
#   'frequency': 1},
#  'increas': {'postings': [(0,
#     'https://notes.bagerbach.com/increase-your-leverage-to-become-more-productive')],
#   'frequency': 1},
#  'your': {'postings': [(1,
#     'https://notes.bagerbach.com/increase-your-leverage-to-become-more-productive')],
#   'frequency': 1},
#  'leverag': {'postings': [(2,
#     'https://notes.bagerbach.com/increase-your-leverage-to-become-more-productive')],
#   'frequency': 1},
#  'becom': {'postings': [(4,
#     'https://notes.bagerbach.com/increase-your-leverage-to-become-more-productive')],
#   'frequency': 1},
#  'more': {'postings': [(5,
#     'https://notes.bagerbach.com/increase-your-leverage-to-become-more-productive')],
#   'frequency': 1},
#  'product': {'postings': [(6,
#     'https://notes.bagerbach.com/increase-your-leverage-to-become-more-productive')],
#   'frequency': 1},
#  'richest': {'postings': [(1,
#     'https://bagerbach.com/books/the-richest-man-in-babylon')],
#   'frequency': 1},
#  'man': {'postings': [(2,
#     'https://bagerbach.com/books/the-richest-man-in-babylon')],
#   'frequency': 1},
#  'in': {'postings': [(3,
#     'https://bagerbach.com/books/the-richest-man-in-babylon')],
#   'frequency': 1},
#  'babylon': {'postings': [(4,
#     'https://bagerbach.com/books/the-richest-man-in-babylon')],
#   'frequency': 1},
#  'georg': {'postings': [(6,
#     'https://bagerbach.com/books/the-richest-man-in-babylon')],
#   'frequency': 1},
#  's.': {'postings': [(7,
#     'https://bagerbach.com/books/the-richest-man-in-babylon')],
#   'frequency': 1},
#  'clason': {'postings': [(8,
#     'https://bagerbach.com/books/the-richest-man-in-babylon')],
#   'frequency': 1},
#  'edit': {'postings': [(0,
#     'https://en.wikipedia.org/w/index.php?title=Talk:Antifragile&action=edit'),
#    (0,
#     'https://en.m.wikipedia.org/w/index.php?title=Alan_Blinder&action=edit'),
#    (0,
#     'https://en.m.wikipedia.org/w/index.php?title=Antifragile_(disambiguation)&action=edit')],
#   'frequency': 3},
#  'talk': {'postings': [(1,
#     'https://en.wikipedia.org/w/index.php?title=Talk:Antifragile&action=edit'),
#    (1, 'https://en.wikipedia.org/wiki/User_talk:Vegaswikian')],
#   'frequency': 2},
#  'discov': {'postings': [(0, 'https://developer.wikimedia.org')],
#   'frequency': 1},
#  'build': {'postings': [(2, 'https://developer.wikimedia.org')],
#   'frequency': 1},
#  'technolog': {'postings': [(4, 'https://developer.wikimedia.org')],
#   'frequency': 1},
#  'develop': {'postings': [(7, 'https://developer.wikimedia.org')],
#   'frequency': 1},
#  'portal': {'postings': [(8, 'https://developer.wikimedia.org')],
#   'frequency': 1},
#  'zero': {'postings': [(0, 'https://notes.bagerbach.com/zero-sum')],
#   'frequency': 1},
#  'sum': {'postings': [(1, 'https://notes.bagerbach.com/zero-sum')],
#   'frequency': 1},
#  'press': {'postings': [(2, 'https://www.wikiwand.com/press')],
#   'frequency': 1},
#  'web': {'postings': [(0, 'https://techcrunch.com/2014/08/07/wikiwand/')],
#   'frequency': 1},
#  'app': {'postings': [(1, 'https://techcrunch.com/2014/08/07/wikiwand/')],
#   'frequency': 1},
#  'rais': {'postings': [(3, 'https://techcrunch.com/2014/08/07/wikiwand/')],
#   'frequency': 1},
#  '$': {'postings': [(4, 'https://techcrunch.com/2014/08/07/wikiwand/')],
#   'frequency': 1},
#  '600,000': {'postings': [(5, 'https://techcrunch.com/2014/08/07/wikiwand/')],
#   'frequency': 1},
#  'give': {'postings': [(7, 'https://techcrunch.com/2014/08/07/wikiwand/')],
#   'frequency': 1},
#  'new': {'postings': [(10, 'https://techcrunch.com/2014/08/07/wikiwand/')],
#   'frequency': 1},
#  'interfac': {'postings': [(11,
#     'https://techcrunch.com/2014/08/07/wikiwand/')],
#   'frequency': 1},
#  '•': {'postings': [(12, 'https://techcrunch.com/2014/08/07/wikiwand/')],
#   'frequency': 1},
#  'techcrunch': {'postings': [(13,
#     'https://techcrunch.com/2014/08/07/wikiwand/')],
#   'frequency': 1},
#  'team': {'postings': [(0,
#     'https://www.thefwa.com/interview/team-at-wikiwand/')],
#   'frequency': 1},
#  'at': {'postings': [(1,
#     'https://www.thefwa.com/interview/team-at-wikiwand/')],
#   'frequency': 1},
#  'fwa': {'postings': [(5,
#     'https://www.thefwa.com/interview/team-at-wikiwand/')],
#   'frequency': 1},
#  'gall': {'postings': [(0, 'https://notes.bagerbach.com/gall-s-law')],
#   'frequency': 1},
#  'law': {'postings': [(2, 'https://notes.bagerbach.com/gall-s-law'),
#    (1, 'https://notes.bagerbach.com/the-law-of-inertia')],
#   'frequency': 2},
#  'disambigu': {'postings': [(2,
#     'https://en.wikipedia.org/wiki/Wikipedia:Disambiguation_pages_with_links'),
#    (3,
#     'https://en.m.wikipedia.org/w/index.php?title=Antifragile_(disambiguation)&action=edit'),
#    (2,
#     'https://en.wikipedia.org/wiki/Wikipedia:Disambiguation_pages_with_links/February_2019')],
#   'frequency': 3},
#  'with': {'postings': [(4,
#     'https://en.wikipedia.org/wiki/Wikipedia:Disambiguation_pages_with_links'),
#    (4,
#     'https://en.wikipedia.org/wiki/Wikipedia:Disambiguation_pages_with_links/February_2019')],
#   'frequency': 2},
#  'file': {'postings': [(0,
#     'https://www.wikiwand.com/en/File:Disambig_gray.svg'),
#    (0, 'https://en.wikipedia.org/wiki/File:Red_star2.png'),
#    (0, 'https://en.wikipedia.org/wiki/File:Rotating_red_star.gif')],
#   'frequency': 3},
#  'disambig': {'postings': [(2,
#     'https://www.wikiwand.com/en/File:Disambig_gray.svg')],
#   'frequency': 1},
#  'gray.svg': {'postings': [(3,
#     'https://www.wikiwand.com/en/File:Disambig_gray.svg')],
#   'frequency': 1},
#  'minim': {'postings': [(0,
#     'https://notes.bagerbach.com/minimize-time-getting-into-position-just-go')],
#   'frequency': 1},
#  'into': {'postings': [(3,
#     'https://notes.bagerbach.com/minimize-time-getting-into-position-just-go')],
#   'frequency': 1},
#  'posit': {'postings': [(4,
#     'https://notes.bagerbach.com/minimize-time-getting-into-position-just-go')],
#   'frequency': 1},
#  ',': {'postings': [(5,
#     'https://notes.bagerbach.com/minimize-time-getting-into-position-just-go'),
#    (12,
#     'https://da.wikipedia.org/wiki/Wikipedia:Artikler_med_flertydige_titler_som_der_henvises_til'),
#    (9, 'https://da.wikipedia.org/wiki/Speciel:Hvad_linker_hertil/B%C3%A5nd'),
#    (5, 'https://da.wikipedia.org/wiki/Hj%C3%A6lp:Forside'),
#    (3, 'https://da.wikipedia.org/wiki/Frekvensb%C3%A5nd'),
#    (9,
#     'https://da.wikipedia.org/w/index.php?title=Speciel:Hvad_linker_hertil/B%C3%A5nd&limit=500'),
#    (4, 'https://da.wikipedia.org/wiki/Speciel:For%C3%A6ldrel%C3%B8se_sider'),
#    (8, 'https://sw.wikipedia.org/wiki/Wikipedia:Msaada_wa_kuanzisha_makala'),
#    (6, 'https://da.wikipedia.org/wiki/Virkning_(flertydig)'),
#    (3, 'https://da.wikipedia.org/wiki/Kup'),
#    (5, 'https://ang.wikipedia.org/wiki/Help:Inno%C3%BE'),
#    (5, 'https://da.wikipedia.org/wiki/Hj%C3%A6lp:Mentorer'),
#    (3,
#     'https://ang.wikipedia.org/w/index.php?title=Syndrig:Book&bookcmd=book_creator&referer=Help%3AInno%C3%BE'),
#    (10,
#     'https://sw.wikipedia.org/wiki/Majadiliano_ya_Wikipedia:Msaada_wa_kuanzisha_makala'),
#    (4, 'https://da.wikipedia.org/wiki/Wayback_Machine')],
#   'frequency': 15},
#  'just': {'postings': [(6,
#     'https://notes.bagerbach.com/minimize-time-getting-into-position-just-go')],
#   'frequency': 1},
#  'go': {'postings': [(7,
#     'https://notes.bagerbach.com/minimize-time-getting-into-position-just-go')],
#   'frequency': 1},
#  'artikl': {'postings': [(2,
#     'https://da.wikipedia.org/wiki/Wikipedia:Artikler_med_flertydige_titler_som_der_henvises_til')],
#   'frequency': 1},
#  'med': {'postings': [(3,
#     'https://da.wikipedia.org/wiki/Wikipedia:Artikler_med_flertydige_titler_som_der_henvises_til')],
#   'frequency': 1},
#  'flertydig': {'postings': [(4,
#     'https://da.wikipedia.org/wiki/Wikipedia:Artikler_med_flertydige_titler_som_der_henvises_til'),
#    (2, 'https://da.wikipedia.org/wiki/Virkning_(flertydig)')],
#   'frequency': 2},
#  'titler': {'postings': [(5,
#     'https://da.wikipedia.org/wiki/Wikipedia:Artikler_med_flertydige_titler_som_der_henvises_til')],
#   'frequency': 1},
#  'som': {'postings': [(6,
#     'https://da.wikipedia.org/wiki/Wikipedia:Artikler_med_flertydige_titler_som_der_henvises_til')],
#   'frequency': 1},
#  'der': {'postings': [(7,
#     'https://da.wikipedia.org/wiki/Wikipedia:Artikler_med_flertydige_titler_som_der_henvises_til'),
#    (1, 'https://da.wikipedia.org/wiki/Speciel:Hvad_linker_hertil/B%C3%A5nd'),
#    (1,
#     'https://da.wikipedia.org/w/index.php?title=Speciel:Hvad_linker_hertil/B%C3%A5nd&limit=500')],
#   'frequency': 3},
#  'henvis': {'postings': [(8,
#     'https://da.wikipedia.org/wiki/Wikipedia:Artikler_med_flertydige_titler_som_der_henvises_til')],
#   'frequency': 1},
#  'til': {'postings': [(9,
#     'https://da.wikipedia.org/wiki/Wikipedia:Artikler_med_flertydige_titler_som_der_henvises_til'),
#    (3, 'https://da.wikipedia.org/wiki/Speciel:Hvad_linker_hertil/B%C3%A5nd'),
#    (3,
#     'https://da.wikipedia.org/w/index.php?title=Speciel:Hvad_linker_hertil/B%C3%A5nd&limit=500')],
#   'frequency': 3},
#  'den': {'postings': [(13,
#     'https://da.wikipedia.org/wiki/Wikipedia:Artikler_med_flertydige_titler_som_der_henvises_til'),
#    (10, 'https://da.wikipedia.org/wiki/Speciel:Hvad_linker_hertil/B%C3%A5nd'),
#    (6, 'https://da.wikipedia.org/wiki/Hj%C3%A6lp:Forside'),
#    (4, 'https://da.wikipedia.org/wiki/Frekvensb%C3%A5nd'),
#    (10,
#     'https://da.wikipedia.org/w/index.php?title=Speciel:Hvad_linker_hertil/B%C3%A5nd&limit=500'),
#    (5, 'https://da.wikipedia.org/wiki/Speciel:For%C3%A6ldrel%C3%B8se_sider'),
#    (7, 'https://da.wikipedia.org/wiki/Virkning_(flertydig)'),
#    (4, 'https://da.wikipedia.org/wiki/Kup'),
#    (6, 'https://da.wikipedia.org/wiki/Hj%C3%A6lp:Mentorer'),
#    (5, 'https://da.wikipedia.org/wiki/Wayback_Machine')],
#   'frequency': 10},
#  'frie': {'postings': [(14,
#     'https://da.wikipedia.org/wiki/Wikipedia:Artikler_med_flertydige_titler_som_der_henvises_til'),
#    (11, 'https://da.wikipedia.org/wiki/Speciel:Hvad_linker_hertil/B%C3%A5nd'),
#    (7, 'https://da.wikipedia.org/wiki/Hj%C3%A6lp:Forside'),
#    (5, 'https://da.wikipedia.org/wiki/Frekvensb%C3%A5nd'),
#    (11,
#     'https://da.wikipedia.org/w/index.php?title=Speciel:Hvad_linker_hertil/B%C3%A5nd&limit=500'),
#    (6, 'https://da.wikipedia.org/wiki/Speciel:For%C3%A6ldrel%C3%B8se_sider'),
#    (8, 'https://da.wikipedia.org/wiki/Virkning_(flertydig)'),
#    (5, 'https://da.wikipedia.org/wiki/Kup'),
#    (7, 'https://da.wikipedia.org/wiki/Hj%C3%A6lp:Mentorer'),
#    (6, 'https://da.wikipedia.org/wiki/Wayback_Machine')],
#   'frequency': 10},
#  'encyklopædi': {'postings': [(15,
#     'https://da.wikipedia.org/wiki/Wikipedia:Artikler_med_flertydige_titler_som_der_henvises_til'),
#    (12, 'https://da.wikipedia.org/wiki/Speciel:Hvad_linker_hertil/B%C3%A5nd'),
#    (8, 'https://da.wikipedia.org/wiki/Hj%C3%A6lp:Forside'),
#    (6, 'https://da.wikipedia.org/wiki/Frekvensb%C3%A5nd'),
#    (12,
#     'https://da.wikipedia.org/w/index.php?title=Speciel:Hvad_linker_hertil/B%C3%A5nd&limit=500'),
#    (7, 'https://da.wikipedia.org/wiki/Speciel:For%C3%A6ldrel%C3%B8se_sider'),
#    (9, 'https://da.wikipedia.org/wiki/Virkning_(flertydig)'),
#    (6, 'https://da.wikipedia.org/wiki/Kup'),
#    (8, 'https://da.wikipedia.org/wiki/Hj%C3%A6lp:Mentorer'),
#    (7, 'https://da.wikipedia.org/wiki/Wayback_Machine')],
#   'frequency': 10},
#  'red': {'postings': [(2, 'https://en.wikipedia.org/wiki/File:Red_star2.png'),
#    (3, 'https://en.wikipedia.org/wiki/File:Rotating_red_star.gif')],
#   'frequency': 2},
#  'star2.png': {'postings': [(3,
#     'https://en.wikipedia.org/wiki/File:Red_star2.png')],
#   'frequency': 1},
#  'person': {'postings': [(1, 'https://bagerbach.com/books/the-personal-mba')],
#   'frequency': 1},
#  'mba': {'postings': [(2, 'https://bagerbach.com/books/the-personal-mba')],
#   'frequency': 1},
#  'josh': {'postings': [(4, 'https://bagerbach.com/books/the-personal-mba')],
#   'frequency': 1},
#  'kaufman': {'postings': [(5, 'https://bagerbach.com/books/the-personal-mba')],
#   'frequency': 1},
#  'foundat': {'postings': [(1, 'https://wikimediafoundation.org/')],
#   'frequency': 1},
#  'signal': {'postings': [(0, 'https://notes.bagerbach.com/signal-vs-noise')],
#   'frequency': 1},
#  'vs': {'postings': [(1, 'https://notes.bagerbach.com/signal-vs-noise')],
#   'frequency': 1},
#  'nois': {'postings': [(3, 'https://notes.bagerbach.com/signal-vs-noise')],
#   'frequency': 1},
#  'sider': {'postings': [(0,
#     'https://da.wikipedia.org/wiki/Speciel:Hvad_linker_hertil/B%C3%A5nd'),
#    (0,
#     'https://da.wikipedia.org/w/index.php?title=Speciel:Hvad_linker_hertil/B%C3%A5nd&limit=500'),
#    (1, 'https://da.wikipedia.org/wiki/Speciel:For%C3%A6ldrel%C3%B8se_sider')],
#   'frequency': 3},
#  'linker': {'postings': [(2,
#     'https://da.wikipedia.org/wiki/Speciel:Hvad_linker_hertil/B%C3%A5nd'),
#    (2,
#     'https://da.wikipedia.org/w/index.php?title=Speciel:Hvad_linker_hertil/B%C3%A5nd&limit=500')],
#   'frequency': 2},
#  'bånd': {'postings': [(5,
#     'https://da.wikipedia.org/wiki/Speciel:Hvad_linker_hertil/B%C3%A5nd'),
#    (5,
#     'https://da.wikipedia.org/w/index.php?title=Speciel:Hvad_linker_hertil/B%C3%A5nd&limit=500')],
#   'frequency': 2},
#  'rotat': {'postings': [(2,
#     'https://en.wikipedia.org/wiki/File:Rotating_red_star.gif')],
#   'frequency': 1},
#  'star.gif': {'postings': [(4,
#     'https://en.wikipedia.org/wiki/File:Rotating_red_star.gif')],
#   'frequency': 1},
#  'scalabl': {'postings': [(0,
#     'https://www.wikiwand.com/en/Scalable_Vector_Graphics')],
#   'frequency': 1},
#  'vector': {'postings': [(1,
#     'https://www.wikiwand.com/en/Scalable_Vector_Graphics'),
#    (2,
#     'https://commons.wikimedia.org/wiki/Template:Vector_version_available/sco')],
#   'frequency': 2},
#  'graphic': {'postings': [(2,
#     'https://www.wikiwand.com/en/Scalable_Vector_Graphics')],
#   'frequency': 1},
#  'vikiprojekt': {'postings': [(0,
#     'https://lv.wikipedia.org/wiki/Vikiprojekts:Vikip%C4%93dijas_uzlabo%C5%A1ana/Noz%C4%ABmju_atdal%C4%AB%C5%A1ana/Noz%C4%ABmju_atdal%C4%AB%C5%A1anas_lapas_ar_sait%C4%93m')],
#   'frequency': 1},
#  'vikipēdija': {'postings': [(2,
#     'https://lv.wikipedia.org/wiki/Vikiprojekts:Vikip%C4%93dijas_uzlabo%C5%A1ana/Noz%C4%ABmju_atdal%C4%AB%C5%A1ana/Noz%C4%ABmju_atdal%C4%AB%C5%A1anas_lapas_ar_sait%C4%93m'),
#    (10,
#     'https://lv.wikipedia.org/wiki/Vikiprojekts:Vikip%C4%93dijas_uzlabo%C5%A1ana/Noz%C4%ABmju_atdal%C4%AB%C5%A1ana/Noz%C4%ABmju_atdal%C4%AB%C5%A1anas_lapas_ar_sait%C4%93m'),
#    (2, 'https://lv.wikipedia.org/wiki/Superl%C4%ABga'),
#    (2, 'https://lv.wikipedia.org/wiki/Vecstropi'),
#    (2, 'https://lv.wikipedia.org/wiki/Liberts'),
#    (2, 'https://lv.wikipedia.org/wiki/Hermes'),
#    (2, 'https://lv.wikipedia.org/wiki/Maguire'),
#    (2, 'https://lv.wikipedia.org/wiki/Dz%C4%93rv%C4%ABte'),
#    (2, 'https://lv.wikipedia.org/wiki/Tom%C4%93ni'),
#    (6,
#     'https://lv.wikipedia.org/wiki/Krons_(noz%C4%ABmju_atdal%C4%AB%C5%A1ana)'),
#    (3, 'https://lv.wikipedia.org/wiki/Stare_Mesto')],
#   'frequency': 11},
#  'uzlabošana/nozīmju': {'postings': [(3,
#     'https://lv.wikipedia.org/wiki/Vikiprojekts:Vikip%C4%93dijas_uzlabo%C5%A1ana/Noz%C4%ABmju_atdal%C4%AB%C5%A1ana/Noz%C4%ABmju_atdal%C4%AB%C5%A1anas_lapas_ar_sait%C4%93m')],
#   'frequency': 1},
#  'atdalīšana/nozīmju': {'postings': [(4,
#     'https://lv.wikipedia.org/wiki/Vikiprojekts:Vikip%C4%93dijas_uzlabo%C5%A1ana/Noz%C4%ABmju_atdal%C4%AB%C5%A1ana/Noz%C4%ABmju_atdal%C4%AB%C5%A1anas_lapas_ar_sait%C4%93m')],
#   'frequency': 1},
#  'atdalīšana': {'postings': [(5,
# ...
#   'frequency': 1},
#  '2019': {'postings': [(6,
#     'https://en.wikipedia.org/wiki/Wikipedia:Disambiguation_pages_with_links/February_2019')],
#   'frequency': 1},
#  'уикипедия': {'postings': [(0,
#     'https://kk.wikipedia.org/wiki/%D0%A3%D0%B8%D0%BA%D0%B8%D0%BF%D0%B5%D0%B4%D0%B8%D1%8F:%D0%90%D0%BD%D1%8B%D2%9B%D1%82%D0%B0%D0%BC%D0%B0'),
#    (4,
#     'https://kk.wikipedia.org/wiki/%D0%A3%D0%B8%D0%BA%D0%B8%D0%BF%D0%B5%D0%B4%D0%B8%D1%8F:%D0%90%D0%BD%D1%8B%D2%9B%D1%82%D0%B0%D0%BC%D0%B0'),
#    (1,
#     'https://kk.wikipedia.org/w/index.php?title=%D0%A3%D0%B8%D0%BA%D0%B8%D0%BF%D0%B5%D0%B4%D0%B8%D1%8F:%D0%90%D0%BD%D1%8B%D2%9B%D1%82%D0%B0%D0%BC%D0%B0&action=info'),
#    (9,
#     'https://kk.wikipedia.org/w/index.php?title=%D0%A3%D0%B8%D0%BA%D0%B8%D0%BF%D0%B5%D0%B4%D0%B8%D1%8F:%D0%90%D0%BD%D1%8B%D2%9B%D1%82%D0%B0%D0%BC%D0%B0&action=info')],
#   'frequency': 4},
#  'анықтама': {'postings': [(2,
#     'https://kk.wikipedia.org/wiki/%D0%A3%D0%B8%D0%BA%D0%B8%D0%BF%D0%B5%D0%B4%D0%B8%D1%8F:%D0%90%D0%BD%D1%8B%D2%9B%D1%82%D0%B0%D0%BC%D0%B0'),
#    (3,
#     'https://kk.wikipedia.org/w/index.php?title=%D0%A3%D0%B8%D0%BA%D0%B8%D0%BF%D0%B5%D0%B4%D0%B8%D1%8F:%D0%90%D0%BD%D1%8B%D2%9B%D1%82%D0%B0%D0%BC%D0%B0&action=info')],
#   'frequency': 2},
#  'help': {'postings': [(0, 'https://bi.wikipedia.org/wiki/Help:Contents'),
#    (0, 'https://ang.wikipedia.org/wiki/Help:Inno%C3%BE')],
#   'frequency': 2},
#  'content': {'postings': [(2, 'https://bi.wikipedia.org/wiki/Help:Contents')],
#   'frequency': 1},
#  'realiti': {'postings': [(0,
#     'https://bagerbach.com/books/reality-is-not-what-it-seems')],
#   'frequency': 1},
#  'is': {'postings': [(1,
#     'https://bagerbach.com/books/reality-is-not-what-it-seems')],
#   'frequency': 1},
#  'not': {'postings': [(2,
#     'https://bagerbach.com/books/reality-is-not-what-it-seems')],
#   'frequency': 1},
#  'seem': {'postings': [(5,
#     'https://bagerbach.com/books/reality-is-not-what-it-seems')],
#   'frequency': 1},
#  'carlo': {'postings': [(7,
#     'https://bagerbach.com/books/reality-is-not-what-it-seems')],
#   'frequency': 1},
#  'rovelli': {'postings': [(8,
#     'https://bagerbach.com/books/reality-is-not-what-it-seems')],
#   'frequency': 1},
#  'ជំនួយ': {'postings': [(0,
#     'https://km.wikipedia.org/wiki/%E1%9E%87%E1%9F%86%E1%9E%93%E1%9E%BD%E1%9E%99:%E1%9E%98%E1%9E%B6%E1%9E%8F%E1%9E%B7%E1%9E%80%E1%9E%B6')],
#   'frequency': 1},
#  'មាតិកា': {'postings': [(2,
#     'https://km.wikipedia.org/wiki/%E1%9E%87%E1%9F%86%E1%9E%93%E1%9E%BD%E1%9E%99:%E1%9E%98%E1%9E%B6%E1%9E%8F%E1%9E%B7%E1%9E%80%E1%9E%B6')],
#   'frequency': 1},
#  'វិគីភីឌា': {'postings': [(4,
#     'https://km.wikipedia.org/wiki/%E1%9E%87%E1%9F%86%E1%9E%93%E1%9E%BD%E1%9E%99:%E1%9E%98%E1%9E%B6%E1%9E%8F%E1%9E%B7%E1%9E%80%E1%9E%B6')],
#   'frequency': 1},
#  'libert': {'postings': [(0, 'https://lv.wikipedia.org/wiki/Liberts')],
#   'frequency': 1},
#  'radio': {'postings': [(0,
#     'https://web.archive.org/web/20030401130935/http://topology.org/comms/radcodes.html')],
#   'frequency': 1},
#  'code': {'postings': [(1,
#     'https://web.archive.org/web/20030401130935/http://topology.org/comms/radcodes.html')],
#   'frequency': 1},
#  'band': {'postings': [(3,
#     'https://web.archive.org/web/20030401130935/http://topology.org/comms/radcodes.html')],
#   'frequency': 1},
#  'anuradha': {'postings': [(0, 'https://en.wikipedia.org/wiki/Anuradha')],
#   'frequency': 1},
#  'herm': {'postings': [(0, 'https://lv.wikipedia.org/wiki/Hermes')],
#   'frequency': 1},
#  'view': {'postings': [(0,
#     'https://en.m.wikipedia.org/w/index.php?title=Module:Yesno&action=edit')],
#   'frequency': 1},
#  'sourc': {'postings': [(1,
#     'https://en.m.wikipedia.org/w/index.php?title=Module:Yesno&action=edit')],
#   'frequency': 1},
#  'for': {'postings': [(2,
#     'https://en.m.wikipedia.org/w/index.php?title=Module:Yesno&action=edit')],
#   'frequency': 1},
#  'modul': {'postings': [(3,
#     'https://en.m.wikipedia.org/w/index.php?title=Module:Yesno&action=edit'),
#    (0, 'https://en.m.wikipedia.org/wiki/Module:Category_handler/blacklist')],
#   'frequency': 2},
#  'yesno': {'postings': [(5,
#     'https://en.m.wikipedia.org/w/index.php?title=Module:Yesno&action=edit')],
#   'frequency': 1},
#  'inertia': {'postings': [(3,
#     'https://notes.bagerbach.com/the-law-of-inertia')],
#   'frequency': 1},
#  'forældreløs': {'postings': [(0,
#     'https://da.wikipedia.org/wiki/Speciel:For%C3%A6ldrel%C3%B8se_sider')],
#   'frequency': 1},
#  'pagelba': {'postings': [(0,
#     'https://bat-smg.wikipedia.org/wiki/Pagelba:Tor%C4%97n%C4%ABs')],
#   'frequency': 1},
#  'torėnī': {'postings': [(2,
#     'https://bat-smg.wikipedia.org/wiki/Pagelba:Tor%C4%97n%C4%ABs')],
#   'frequency': 1},
#  'leader': {'postings': [(0, 'https://bagerbach.com/books/leaders-eat-last')],
#   'frequency': 1},
#  'eat': {'postings': [(1, 'https://bagerbach.com/books/leaders-eat-last')],
#   'frequency': 1},
#  'last': {'postings': [(2, 'https://bagerbach.com/books/leaders-eat-last')],
#   'frequency': 1},
#  'simon': {'postings': [(4, 'https://bagerbach.com/books/leaders-eat-last')],
#   'frequency': 1},
#  'sinek': {'postings': [(5, 'https://bagerbach.com/books/leaders-eat-last')],
#   'frequency': 1},
#  'charl': {'postings': [(0, 'https://en.wikipedia.org/wiki/Charles_Taylor')],
#   'frequency': 1},
#  'taylor': {'postings': [(1, 'https://en.wikipedia.org/wiki/Charles_Taylor')],
#   'frequency': 1},
#  'maguir': {'postings': [(0, 'https://lv.wikipedia.org/wiki/Maguire')],
#   'frequency': 1},
#  'hilf': {'postings': [(2, 'https://als.wikipedia.org/wiki/Wikipedia:Hilfe')],
#   'frequency': 1},
#  'alemannisch': {'postings': [(4,
#     'https://als.wikipedia.org/wiki/Wikipedia:Hilfe'),
#    (6, 'https://als.wikipedia.org/wiki/Spezial:Myyni_Byytreeg')],
#   'frequency': 2},
#  'msaada': {'postings': [(2,
#     'https://sw.wikipedia.org/wiki/Wikipedia:Msaada_wa_kuanzisha_makala'),
#    (4,
#     'https://sw.wikipedia.org/wiki/Majadiliano_ya_Wikipedia:Msaada_wa_kuanzisha_makala')],
#   'frequency': 2},
#  'wa': {'postings': [(3,
#     'https://sw.wikipedia.org/wiki/Wikipedia:Msaada_wa_kuanzisha_makala'),
#    (5,
#     'https://sw.wikipedia.org/wiki/Majadiliano_ya_Wikipedia:Msaada_wa_kuanzisha_makala')],
#   'frequency': 2},
#  'kuanzisha': {'postings': [(4,
#     'https://sw.wikipedia.org/wiki/Wikipedia:Msaada_wa_kuanzisha_makala'),
#    (6,
#     'https://sw.wikipedia.org/wiki/Majadiliano_ya_Wikipedia:Msaada_wa_kuanzisha_makala')],
#   'frequency': 2},
#  'makala': {'postings': [(5,
#     'https://sw.wikipedia.org/wiki/Wikipedia:Msaada_wa_kuanzisha_makala'),
#    (7,
#     'https://sw.wikipedia.org/wiki/Majadiliano_ya_Wikipedia:Msaada_wa_kuanzisha_makala')],
#   'frequency': 2},
#  'kamusi': {'postings': [(9,
#     'https://sw.wikipedia.org/wiki/Wikipedia:Msaada_wa_kuanzisha_makala'),
#    (11,
#     'https://sw.wikipedia.org/wiki/Majadiliano_ya_Wikipedia:Msaada_wa_kuanzisha_makala')],
#   'frequency': 2},
#  'elezo': {'postings': [(10,
#     'https://sw.wikipedia.org/wiki/Wikipedia:Msaada_wa_kuanzisha_makala'),
#    (12,
#     'https://sw.wikipedia.org/wiki/Majadiliano_ya_Wikipedia:Msaada_wa_kuanzisha_makala')],
#   'frequency': 2},
#  'huru': {'postings': [(11,
#     'https://sw.wikipedia.org/wiki/Wikipedia:Msaada_wa_kuanzisha_makala'),
#    (13,
#     'https://sw.wikipedia.org/wiki/Majadiliano_ya_Wikipedia:Msaada_wa_kuanzisha_makala')],
#   'frequency': 2},
#  'тусламж': {'postings': [(0,
#     'https://mn.wikipedia.org/wiki/%D0%A2%D1%83%D1%81%D0%BB%D0%B0%D0%BC%D0%B6:%D0%90%D0%B3%D1%83%D1%83%D0%BB%D0%B3%D0%B0')],
#   'frequency': 1},
#  'агуулга': {'postings': [(2,
#     'https://mn.wikipedia.org/wiki/%D0%A2%D1%83%D1%81%D0%BB%D0%B0%D0%BC%D0%B6:%D0%90%D0%B3%D1%83%D1%83%D0%BB%D0%B3%D0%B0')],
#   'frequency': 1},
#  'википедиа': {'postings': [(4,
#     'https://mn.wikipedia.org/wiki/%D0%A2%D1%83%D1%81%D0%BB%D0%B0%D0%BC%D0%B6:%D0%90%D0%B3%D1%83%D1%83%D0%BB%D0%B3%D0%B0')],
#   'frequency': 1},
#  'нэвтэрхий': {'postings': [(5,
#     'https://mn.wikipedia.org/wiki/%D0%A2%D1%83%D1%81%D0%BB%D0%B0%D0%BC%D0%B6:%D0%90%D0%B3%D1%83%D1%83%D0%BB%D0%B3%D0%B0')],
#   'frequency': 1},
#  'толь': {'postings': [(6,
#     'https://mn.wikipedia.org/wiki/%D0%A2%D1%83%D1%81%D0%BB%D0%B0%D0%BC%D0%B6:%D0%90%D0%B3%D1%83%D1%83%D0%BB%D0%B3%D0%B0')],
#   'frequency': 1},
#  'virkn': {'postings': [(0,
#     'https://da.wikipedia.org/wiki/Virkning_(flertydig)')],
#   'frequency': 1},
#  'deputi': {'postings': [(0, 'https://en.wikipedia.org/wiki/Deputy'),
#    (0, 'https://en.wikipedia.org/wiki/Deputy_mayor')],
#   'frequency': 2},
#  'opportun': {'postings': [(0,
#     'https://notes.bagerbach.com/opportunity-cost')],
#   'frequency': 1},
#  'cost': {'postings': [(1, 'https://notes.bagerbach.com/opportunity-cost')],
#   'frequency': 1},
#  'dzērvīte': {'postings': [(0,
#     'https://lv.wikipedia.org/wiki/Dz%C4%93rv%C4%ABte')],
#   'frequency': 1},
#  'anyth': {'postings': [(0, 'https://bagerbach.com/books/anything-you-want')],
#   'frequency': 1},
#  'you': {'postings': [(1, 'https://bagerbach.com/books/anything-you-want')],
#   'frequency': 1},
#  'want': {'postings': [(2, 'https://bagerbach.com/books/anything-you-want')],
#   'frequency': 1},
#  'derek': {'postings': [(4, 'https://bagerbach.com/books/anything-you-want')],
#   'frequency': 1},
#  'siver': {'postings': [(5, 'https://bagerbach.com/books/anything-you-want')],
#   'frequency': 1},
#  'categori': {'postings': [(2,
#     'https://en.m.wikipedia.org/wiki/Module:Category_handler/blacklist')],
#   'frequency': 1},
#  'handler/blacklist': {'postings': [(3,
#     'https://en.m.wikipedia.org/wiki/Module:Category_handler/blacklist')],
#   'frequency': 1},
#  'ಸಹಾಯ': {'postings': [(0,
#     'https://kn.wikipedia.org/wiki/%E0%B2%B8%E0%B2%B9%E0%B2%BE%E0%B2%AF:%E0%B2%AA%E0%B2%B0%E0%B2%BF%E0%B2%B5%E0%B2%BF%E0%B2%A1%E0%B2%BF')],
#   'frequency': 1},
#  'ಪರಿವಿಡಿ': {'postings': [(2,
#     'https://kn.wikipedia.org/wiki/%E0%B2%B8%E0%B2%B9%E0%B2%BE%E0%B2%AF:%E0%B2%AA%E0%B2%B0%E0%B2%BF%E0%B2%B5%E0%B2%BF%E0%B2%A1%E0%B2%BF')],
#   'frequency': 1},
#  'ವಿಕಿಪೀಡಿಯ': {'postings': [(4,
#     'https://kn.wikipedia.org/wiki/%E0%B2%B8%E0%B2%B9%E0%B2%BE%E0%B2%AF:%E0%B2%AA%E0%B2%B0%E0%B2%BF%E0%B2%B5%E0%B2%BF%E0%B2%A1%E0%B2%BF')],
#   'frequency': 1},
#  'version': {'postings': [(3,
#     'https://commons.wikimedia.org/wiki/Template:Vector_version_available/sco')],
#   'frequency': 1},
#  'available/sco': {'postings': [(4,
#     'https://commons.wikimedia.org/wiki/Template:Vector_version_available/sco')],
#   'frequency': 1},
#  'common': {'postings': [(7,
#     'https://commons.wikimedia.org/wiki/Template:Vector_version_available/sco')],
#   'frequency': 1},
#  'cso': {'postings': [(0, 'https://en.wikipedia.org/wiki/CSO')],
#   'frequency': 1},
#  'tomēni': {'postings': [(0, 'https://lv.wikipedia.org/wiki/Tom%C4%93ni')],
#   'frequency': 1},
#  'kup': {'postings': [(0, 'https://da.wikipedia.org/wiki/Kup')],
#   'frequency': 1},
#  'wikidata': {'postings': [(2,
#     'https://www.wikidata.org/wiki/Special:EntityPage/Q16355515')],
#   'frequency': 1},
#  'innoþ': {'postings': [(2, 'https://ang.wikipedia.org/wiki/Help:Inno%C3%BE')],
#   'frequency': 1},
#  'wikipǣdia': {'postings': [(4,
#     'https://ang.wikipedia.org/wiki/Help:Inno%C3%BE'),
#    (2,
#     'https://ang.wikipedia.org/w/index.php?title=Syndrig:Book&bookcmd=book_creator&referer=Help%3AInno%C3%BE')],
#   'frequency': 2},
#  'sēo': {'postings': [(6, 'https://ang.wikipedia.org/wiki/Help:Inno%C3%BE'),
#    (4,
#     'https://ang.wikipedia.org/w/index.php?title=Syndrig:Book&bookcmd=book_creator&referer=Help%3AInno%C3%BE')],
#   'frequency': 2},
#  'frēo': {'postings': [(7, 'https://ang.wikipedia.org/wiki/Help:Inno%C3%BE'),
#    (5,
#     'https://ang.wikipedia.org/w/index.php?title=Syndrig:Book&bookcmd=book_creator&referer=Help%3AInno%C3%BE')],
#   'frequency': 2},
#  'wīsdōmbōc': {'postings': [(8,
#     'https://ang.wikipedia.org/wiki/Help:Inno%C3%BE'),
#    (6,
#     'https://ang.wikipedia.org/w/index.php?title=Syndrig:Book&bookcmd=book_creator&referer=Help%3AInno%C3%BE')],
#   'frequency': 2},
#  '«': {'postings': [(0,
#     'https://kk.wikipedia.org/w/index.php?title=%D0%A3%D0%B8%D0%BA%D0%B8%D0%BF%D0%B5%D0%B4%D0%B8%D1%8F:%D0%90%D0%BD%D1%8B%D2%9B%D1%82%D0%B0%D0%BC%D0%B0&action=info')],
#   'frequency': 1},
#  '»': {'postings': [(4,
#     'https://kk.wikipedia.org/w/index.php?title=%D0%A3%D0%B8%D0%BA%D0%B8%D0%BF%D0%B5%D0%B4%D0%B8%D1%8F:%D0%90%D0%BD%D1%8B%D2%9B%D1%82%D0%B0%D0%BC%D0%B0&action=info')],
#   'frequency': 1},
#  'беті': {'postings': [(5,
#     'https://kk.wikipedia.org/w/index.php?title=%D0%A3%D0%B8%D0%BA%D0%B8%D0%BF%D0%B5%D0%B4%D0%B8%D1%8F:%D0%90%D0%BD%D1%8B%D2%9B%D1%82%D0%B0%D0%BC%D0%B0&action=info')],
#   'frequency': 1},
#  'туралы': {'postings': [(6,
#     'https://kk.wikipedia.org/w/index.php?title=%D0%A3%D0%B8%D0%BA%D0%B8%D0%BF%D0%B5%D0%B4%D0%B8%D1%8F:%D0%90%D0%BD%D1%8B%D2%9B%D1%82%D0%B0%D0%BC%D0%B0&action=info')],
#   'frequency': 1},
#  'мәлімет': {'postings': [(7,
#     'https://kk.wikipedia.org/w/index.php?title=%D0%A3%D0%B8%D0%BA%D0%B8%D0%BF%D0%B5%D0%B4%D0%B8%D1%8F:%D0%90%D0%BD%D1%8B%D2%9B%D1%82%D0%B0%D0%BC%D0%B0&action=info')],
#   'frequency': 1},
#  'kron': {'postings': [(0,
#     'https://lv.wikipedia.org/wiki/Krons_(noz%C4%ABmju_atdal%C4%AB%C5%A1ana)')],
#   'frequency': 1},
#  'nozīmju': {'postings': [(2,
#     'https://lv.wikipedia.org/wiki/Krons_(noz%C4%ABmju_atdal%C4%AB%C5%A1ana)')],
#   'frequency': 1},
#  'tabang': {'postings': [(0,
#     'https://ceb.wikipedia.org/wiki/Tabang:Mga_sulod')],
#   'frequency': 1},
#  'mga': {'postings': [(2, 'https://ceb.wikipedia.org/wiki/Tabang:Mga_sulod')],
#   'frequency': 1},
#  'sulod': {'postings': [(3,
#     'https://ceb.wikipedia.org/wiki/Tabang:Mga_sulod')],
#   'frequency': 1},
#  'mayor': {'postings': [(1, 'https://en.wikipedia.org/wiki/Deputy_mayor')],
#   'frequency': 1},
#  'super': {'postings': [(0, 'https://et.wikipedia.org/wiki/Super_League')],
#   'frequency': 1},
#  'leagu': {'postings': [(1, 'https://et.wikipedia.org/wiki/Super_League')],
#   'frequency': 1},
#  '–': {'postings': [(2, 'https://et.wikipedia.org/wiki/Super_League')],
#   'frequency': 1},
#  'vikipeedia': {'postings': [(3,
#     'https://et.wikipedia.org/wiki/Super_League')],
#   'frequency': 1},
#  'mentor': {'postings': [(2,
#     'https://da.wikipedia.org/wiki/Hj%C3%A6lp:Mentorer')],
#   'frequency': 1},
#  'википедия': {'postings': [(0,
#     'https://tt.wikipedia.org/wiki/%D0%92%D0%B8%D0%BA%D0%B8%D0%BF%D0%B5%D0%B4%D0%B8%D1%8F:%D0%AF%D1%80%D0%B4%D3%99%D0%BC')],
#   'frequency': 1},
#  'ярдәм': {'postings': [(2,
#     'https://tt.wikipedia.org/wiki/%D0%92%D0%B8%D0%BA%D0%B8%D0%BF%D0%B5%D0%B4%D0%B8%D1%8F:%D0%AF%D1%80%D0%B4%D3%99%D0%BC')],
#   'frequency': 1},
#  'benutzerbyytreg': {'postings': [(0,
#     'https://als.wikipedia.org/wiki/Spezial:Myyni_Byytreeg')],
#   'frequency': 1},
#  'vu': {'postings': [(1,
#     'https://als.wikipedia.org/wiki/Spezial:Myyni_Byytreeg')],
#   'frequency': 1},
#  '„': {'postings': [(2,
#     'https://als.wikipedia.org/wiki/Spezial:Myyni_Byytreeg')],
#   'frequency': 1},
#  '212.112.150.36': {'postings': [(3,
#     'https://als.wikipedia.org/wiki/Spezial:Myyni_Byytreeg')],
#   'frequency': 1},
#  '“': {'postings': [(4,
#     'https://als.wikipedia.org/wiki/Spezial:Myyni_Byytreeg')],
#   'frequency': 1},
#  'black': {'postings': [(0, 'https://notes.bagerbach.com/black-swan')],
#   'frequency': 1},
#  'swan': {'postings': [(1, 'https://notes.bagerbach.com/black-swan')],
#   'frequency': 1},
#  'stare': {'postings': [(0, 'https://lv.wikipedia.org/wiki/Stare_Mesto')],
#   'frequency': 1},
#  'mesto': {'postings': [(1, 'https://lv.wikipedia.org/wiki/Stare_Mesto')],
#   'frequency': 1},
#  'bocscyppend': {'postings': [(0,
#     'https://ang.wikipedia.org/w/index.php?title=Syndrig:Book&bookcmd=book_creator&referer=Help%3AInno%C3%BE')],
#   'frequency': 1},
#  'mediawiki': {'postings': [(0, 'https://www.mediawiki.org/')],
#   'frequency': 1},
#  'majadiliano': {'postings': [(0,
#     'https://sw.wikipedia.org/wiki/Majadiliano_ya_Wikipedia:Msaada_wa_kuanzisha_makala')],
#   'frequency': 1},
#  'ya': {'postings': [(1,
#     'https://sw.wikipedia.org/wiki/Majadiliano_ya_Wikipedia:Msaada_wa_kuanzisha_makala')],
#   'frequency': 1},
#  'chamoy': {'postings': [(0, 'https://en.wikipedia.org/wiki/Chamoy')],
#   'frequency': 1},
#  'wayback': {'postings': [(0,
#     'https://da.wikipedia.org/wiki/Wayback_Machine')],
#   'frequency': 1},
#  'machin': {'postings': [(1, 'https://da.wikipedia.org/wiki/Wayback_Machine')],
#   'frequency': 1}}

# %%
# calculate IDF for all terms in the vocabulary
import math

N = len(visited)

for key in inverted_index:
    inverted_index[key]["idf"] = math.log(N / inverted_index[key]["frequency"])
    
inverted_index
# Out:
# {'home': {'postings': [(0, 'https://notes.bagerbach.com'),
#    (2, 'https://www.wikiwand.com/')],
#   'frequency': 2,
#   'idf': 6.448097941790546},
#  '|': {'postings': [(1, 'https://notes.bagerbach.com'),
#    (1, 'https://bagerbach.com/books'),
#    (3, 'https://notes.bagerbach.com/the-barbell-strategy'),
#    (9, 'https://bagerbach.com/books/the-go-giver'),
#    (18, 'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it'),
#    (8, 'https://notes.bagerbach.com/pp-6-declaring-types-and-type-classes'),
#    (12, 'https://bagerbach.com/books/a-brief-history-of-time'),
#    (2, 'https://notes.bagerbach.com/innovation-multiplier'),
#    (7,
#     'https://notes.bagerbach.com/increase-your-leverage-to-become-more-productive'),
#    (13, 'https://bagerbach.com/books/the-richest-man-in-babylon'),
#    (2, 'https://notes.bagerbach.com/zero-sum'),
#    (3, 'https://notes.bagerbach.com/gall-s-law'),
#    (8,
#     'https://notes.bagerbach.com/minimize-time-getting-into-position-just-go'),
#    (10, 'https://bagerbach.com/books/the-personal-mba'),
#    (4, 'https://notes.bagerbach.com/signal-vs-noise'),
#    (3, 'https://notes.bagerbach.com/the-diderot-effect'),
#    (3, 'https://notes.bagerbach.com/the-pratfall-effect'),
#    (13, 'https://bagerbach.com/books/reality-is-not-what-it-seems'),
#    (4, 'https://notes.bagerbach.com/the-law-of-inertia'),
#    (10, 'https://bagerbach.com/books/leaders-eat-last'),
#    (2, 'https://notes.bagerbach.com/opportunity-cost'),
#    (10, 'https://bagerbach.com/books/anything-you-want'),
#    (1, 'https://notes.bagerbach.com/antifragile'),
#    (2, 'https://notes.bagerbach.com/black-swan')],
#   'frequency': 24,
#   'idf': 3.9631912920025454},
#  'christian': {'postings': [(2, 'https://notes.bagerbach.com'),
#    (2, 'https://bagerbach.com/books'),
#    (4, 'https://notes.bagerbach.com/the-barbell-strategy'),
#    (10, 'https://bagerbach.com/books/the-go-giver'),
#    (19, 'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it'),
#    (9, 'https://notes.bagerbach.com/pp-6-declaring-types-and-type-classes'),
#    (13, 'https://bagerbach.com/books/a-brief-history-of-time'),
#    (3, 'https://notes.bagerbach.com/innovation-multiplier'),
#    (8,
#     'https://notes.bagerbach.com/increase-your-leverage-to-become-more-productive'),
#    (14, 'https://bagerbach.com/books/the-richest-man-in-babylon'),
#    (3, 'https://notes.bagerbach.com/zero-sum'),
#    (4, 'https://notes.bagerbach.com/gall-s-law'),
#    (9,
#     'https://notes.bagerbach.com/minimize-time-getting-into-position-just-go'),
#    (11, 'https://bagerbach.com/books/the-personal-mba'),
#    (5, 'https://notes.bagerbach.com/signal-vs-noise'),
#    (4, 'https://notes.bagerbach.com/the-diderot-effect'),
#    (4, 'https://notes.bagerbach.com/the-pratfall-effect'),
#    (14, 'https://bagerbach.com/books/reality-is-not-what-it-seems'),
#    (5, 'https://notes.bagerbach.com/the-law-of-inertia'),
#    (11, 'https://bagerbach.com/books/leaders-eat-last'),
#    (3, 'https://notes.bagerbach.com/opportunity-cost'),
#    (11, 'https://bagerbach.com/books/anything-you-want'),
#    (2, 'https://notes.bagerbach.com/antifragile'),
#    (3, 'https://notes.bagerbach.com/black-swan')],
#   'frequency': 24,
#   'idf': 3.9631912920025454},
#  "'s": {'postings': [(3, 'https://notes.bagerbach.com'),
#    (5, 'https://notes.bagerbach.com/the-barbell-strategy'),
#    (10, 'https://notes.bagerbach.com/pp-6-declaring-types-and-type-classes'),
#    (4, 'https://notes.bagerbach.com/innovation-multiplier'),
#    (1,
#     'https://templatecount.toolforge.org/index.php?lang=en&namespace=0&name=Antifragile'),
#    (9,
#     'https://notes.bagerbach.com/increase-your-leverage-to-become-more-productive'),
#    (4, 'https://notes.bagerbach.com/zero-sum'),
#    (1, 'https://notes.bagerbach.com/gall-s-law'),
#    (5, 'https://notes.bagerbach.com/gall-s-law'),
#    (10,
#     'https://notes.bagerbach.com/minimize-time-getting-into-position-just-go'),
#    (6, 'https://notes.bagerbach.com/signal-vs-noise'),
#    (5, 'https://notes.bagerbach.com/the-diderot-effect'),
#    (5, 'https://notes.bagerbach.com/the-pratfall-effect'),
#    (6, 'https://notes.bagerbach.com/the-law-of-inertia'),
#    (4, 'https://notes.bagerbach.com/opportunity-cost'),
#    (3, 'https://notes.bagerbach.com/antifragile'),
#    (4, 'https://notes.bagerbach.com/black-swan')],
#   'frequency': 17,
#   'idf': 4.308031778294275},
#  'note': {'postings': [(4, 'https://notes.bagerbach.com'),
#    (6, 'https://notes.bagerbach.com/the-barbell-strategy'),
#    (8, 'https://bagerbach.com/books/the-go-giver'),
#    (17, 'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it'),
#    (11, 'https://notes.bagerbach.com/pp-6-declaring-types-and-type-classes'),
#    (11, 'https://bagerbach.com/books/a-brief-history-of-time'),
#    (5, 'https://notes.bagerbach.com/innovation-multiplier'),
#    (10,
#     'https://notes.bagerbach.com/increase-your-leverage-to-become-more-productive'),
#    (12, 'https://bagerbach.com/books/the-richest-man-in-babylon'),
#    (5, 'https://notes.bagerbach.com/zero-sum'),
#    (6, 'https://notes.bagerbach.com/gall-s-law'),
#    (11,
#     'https://notes.bagerbach.com/minimize-time-getting-into-position-just-go'),
#    (9, 'https://bagerbach.com/books/the-personal-mba'),
#    (7, 'https://notes.bagerbach.com/signal-vs-noise'),
#    (6, 'https://notes.bagerbach.com/the-diderot-effect'),
#    (6, 'https://notes.bagerbach.com/the-pratfall-effect'),
#    (12, 'https://bagerbach.com/books/reality-is-not-what-it-seems'),
#    (7, 'https://notes.bagerbach.com/the-law-of-inertia'),
#    (9, 'https://bagerbach.com/books/leaders-eat-last'),
#    (5, 'https://notes.bagerbach.com/opportunity-cost'),
#    (9, 'https://bagerbach.com/books/anything-you-want'),
#    (4, 'https://notes.bagerbach.com/antifragile'),
#    (5, 'https://notes.bagerbach.com/black-swan')],
#   'frequency': 23,
#   'idf': 4.0057509064213415},
#  'book': {'postings': [(0, 'https://bagerbach.com/books')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'b': {'postings': [(3, 'https://bagerbach.com/books'),
#    (11, 'https://bagerbach.com/books/the-go-giver'),
#    (20, 'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it'),
#    (14, 'https://bagerbach.com/books/a-brief-history-of-time'),
#    (15, 'https://bagerbach.com/books/the-richest-man-in-babylon'),
#    (12, 'https://bagerbach.com/books/the-personal-mba'),
#    (15, 'https://bagerbach.com/books/reality-is-not-what-it-seems'),
#    (12, 'https://bagerbach.com/books/leaders-eat-last'),
#    (12, 'https://bagerbach.com/books/anything-you-want')],
#   'frequency': 9,
#   'idf': 4.944020545014272},
#  '.': {'postings': [(4, 'https://bagerbach.com/books'),
#    (12, 'https://bagerbach.com/books/the-go-giver'),
#    (21, 'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it'),
#    (15, 'https://bagerbach.com/books/a-brief-history-of-time'),
#    (16, 'https://bagerbach.com/books/the-richest-man-in-babylon'),
#    (13, 'https://bagerbach.com/books/the-personal-mba'),
#    (2, 'https://notes.bagerbach.com/signal-vs-noise'),
#    (16, 'https://bagerbach.com/books/reality-is-not-what-it-seems'),
#    (13, 'https://bagerbach.com/books/leaders-eat-last'),
#    (13, 'https://bagerbach.com/books/anything-you-want')],
#   'frequency': 10,
#   'idf': 4.838660029356445},
#  'b.': {'postings': [(5, 'https://bagerbach.com/books'),
#    (13, 'https://bagerbach.com/books/the-go-giver'),
#    (22, 'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it'),
#    (16, 'https://bagerbach.com/books/a-brief-history-of-time'),
#    (17, 'https://bagerbach.com/books/the-richest-man-in-babylon'),
#    (14, 'https://bagerbach.com/books/the-personal-mba'),
#    (17, 'https://bagerbach.com/books/reality-is-not-what-it-seems'),
#    (14, 'https://bagerbach.com/books/leaders-eat-last'),
#    (14, 'https://bagerbach.com/books/anything-you-want')],
#   'frequency': 9,
#   'idf': 4.944020545014272},
#  'houmann': {'postings': [(6, 'https://bagerbach.com/books'),
#    (14, 'https://bagerbach.com/books/the-go-giver'),
#    (23, 'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it'),
#    (17, 'https://bagerbach.com/books/a-brief-history-of-time'),
#    (18, 'https://bagerbach.com/books/the-richest-man-in-babylon'),
#    (15, 'https://bagerbach.com/books/the-personal-mba'),
#    (18, 'https://bagerbach.com/books/reality-is-not-what-it-seems'),
#    (15, 'https://bagerbach.com/books/leaders-eat-last'),
#    (15, 'https://bagerbach.com/books/anything-you-want')],
#   'frequency': 9,
#   'idf': 4.944020545014272},
#  'the': {'postings': [(0, 'https://notes.bagerbach.com/the-barbell-strategy'),
#    (0, 'https://bagerbach.com/books/the-go-giver'),
#    (0, 'https://bagerbach.com/books/the-richest-man-in-babylon'),
#    (4, 'https://www.thefwa.com/interview/team-at-wikiwand/'),
#    (0, 'https://bagerbach.com/books/the-personal-mba'),
#    (0, 'https://notes.bagerbach.com/the-diderot-effect'),
#    (0, 'https://notes.bagerbach.com/the-pratfall-effect'),
#    (0, 'https://notes.bagerbach.com/the-law-of-inertia')],
#   'frequency': 8,
#   'idf': 5.061803580670655},
#  'barbel': {'postings': [(1,
#     'https://notes.bagerbach.com/the-barbell-strategy')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'strategi': {'postings': [(2,
#     'https://notes.bagerbach.com/the-barbell-strategy')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'go-giv': {'postings': [(1, 'https://bagerbach.com/books/the-go-giver')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'by': {'postings': [(2, 'https://bagerbach.com/books/the-go-giver'),
#    (11, 'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it'),
#    (5, 'https://bagerbach.com/books/a-brief-history-of-time'),
#    (5, 'https://bagerbach.com/books/the-richest-man-in-babylon'),
#    (3, 'https://bagerbach.com/books/the-personal-mba'),
#    (6, 'https://bagerbach.com/books/reality-is-not-what-it-seems'),
#    (3, 'https://bagerbach.com/books/leaders-eat-last'),
#    (3, 'https://bagerbach.com/books/anything-you-want')],
#   'frequency': 8,
#   'idf': 5.061803580670655},
#  'bob': {'postings': [(3, 'https://bagerbach.com/books/the-go-giver')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'burg': {'postings': [(4, 'https://bagerbach.com/books/the-go-giver')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  '-': {'postings': [(5, 'https://bagerbach.com/books/the-go-giver'),
#    (1, 'https://www.wikiwand.com/en/Antifragile#/Barbell_strategy'),
#    (14, 'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it'),
#    (2, 'https://notes.bagerbach.com/pp-6-declaring-types-and-type-classes'),
#    (2, 'https://www.wikiwand.com/privacy'),
#    (7,
#     'https://en.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0'),
#    (7,
#     'https://en.m.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0&mobileaction=toggle_view_mobile'),
#    (8, 'https://bagerbach.com/books/a-brief-history-of-time'),
#    (7, 'https://en.wikipedia.org/wiki/Special:WhatLinksHere/Antifragile'),
#    (1, 'https://www.wikiwand.com/contact'),
#    (4,
#     'https://chrome.google.com/webstore/detail/wikiwand-wikipedia-modern/emffkefkbkpkgpdeeooapgaicgmcbolj'),
#    (4,
#     'https://templatecount.toolforge.org/index.php?lang=en&namespace=0&name=Antifragile'),
#    (1, 'https://www.wikiwand.com/'),
#    (9, 'https://bagerbach.com/books/the-richest-man-in-babylon'),
#    (4,
#     'https://en.wikipedia.org/w/index.php?title=Talk:Antifragile&action=edit'),
#    (5, 'https://developer.wikimedia.org'),
#    (1, 'https://www.wikiwand.com/press'),
#    (3, 'https://www.thefwa.com/interview/team-at-wikiwand/'),
#    (6,
#     'https://en.wikipedia.org/wiki/Wikipedia:Disambiguation_pages_with_links'),
#    (4, 'https://www.wikiwand.com/en/File:Disambig_gray.svg'),
#    (7,
#     'https://en.m.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0&limit=100'),
#    (10,
#     'https://da.wikipedia.org/wiki/Wikipedia:Artikler_med_flertydige_titler_som_der_henvises_til'),
#    (4, 'https://en.wikipedia.org/wiki/File:Red_star2.png'),
#    (6, 'https://bagerbach.com/books/the-personal-mba'),
#    (7, 'https://da.wikipedia.org/wiki/Speciel:Hvad_linker_hertil/B%C3%A5nd'),
#    (5, 'https://en.wikipedia.org/wiki/File:Rotating_red_star.gif'),
#    (3, 'https://www.wikiwand.com/en/Scalable_Vector_Graphics'),
#    (2, 'https://en.wikipedia.org/wiki/Lee_Jenkins'),
#    (3, 'https://da.wikipedia.org/wiki/Hj%C3%A6lp:Forside'),
#    (3,
#     'https://en.m.wikipedia.org/w/index.php?title=Alan_Blinder&action=edit'),
#    (4, 'https://en.wikipedia.org/wiki/User_talk:Vegaswikian'),
#    (1, 'https://da.wikipedia.org/wiki/Frekvensb%C3%A5nd'),
#    (3, 'https://min.wikipedia.org/wiki/Bantuan:Isi'),
#    (5,
#     'https://en.m.wikipedia.org/w/index.php?title=Antifragile_(disambiguation)&action=edit'),
#    (7,
#     'https://en.wikipedia.org/wiki/Wikipedia:Disambiguation_pages_with_links/February_2019'),
#    (7,
#     'https://da.wikipedia.org/w/index.php?title=Speciel:Hvad_linker_hertil/B%C3%A5nd&limit=500'),
#    (3, 'https://bi.wikipedia.org/wiki/Help:Contents'),
#    (9, 'https://bagerbach.com/books/reality-is-not-what-it-seems'),
#    (3,
#     'https://km.wikipedia.org/wiki/%E1%9E%87%E1%9F%86%E1%9E%93%E1%9E%BD%E1%9E%99:%E1%9E%98%E1%9E%B6%E1%9E%8F%E1%9E%B7%E1%9E%80%E1%9E%B6'),
#    (1, 'https://en.wikipedia.org/wiki/Anuradha'),
#    (6,
#     'https://en.m.wikipedia.org/w/index.php?title=Module:Yesno&action=edit'),
#    (2, 'https://da.wikipedia.org/wiki/Speciel:For%C3%A6ldrel%C3%B8se_sider'),
#    (3, 'https://bat-smg.wikipedia.org/wiki/Pagelba:Tor%C4%97n%C4%ABs'),
#    (6, 'https://bagerbach.com/books/leaders-eat-last'),
#    (2, 'https://en.wikipedia.org/wiki/Charles_Taylor'),
#    (3, 'https://als.wikipedia.org/wiki/Wikipedia:Hilfe'),
#    (6, 'https://sw.wikipedia.org/wiki/Wikipedia:Msaada_wa_kuanzisha_makala'),
#    (4, 'https://da.wikipedia.org/wiki/Virkning_(flertydig)'),
#    (1, 'https://en.wikipedia.org/wiki/Deputy'),
#    (6, 'https://bagerbach.com/books/anything-you-want'),
#    (4, 'https://en.m.wikipedia.org/wiki/Module:Category_handler/blacklist'),
#    (3,
#     'https://kn.wikipedia.org/wiki/%E0%B2%B8%E0%B2%B9%E0%B2%BE%E0%B2%AF:%E0%B2%AA%E0%B2%B0%E0%B2%BF%E0%B2%B5%E0%B2%BF%E0%B2%A1%E0%B2%BF'),
#    (5,
#     'https://commons.wikimedia.org/wiki/Template:Vector_version_available/sco'),
#    (1, 'https://en.wikipedia.org/wiki/CSO'),
#    (1, 'https://da.wikipedia.org/wiki/Kup'),
#    (1, 'https://www.wikidata.org/wiki/Special:EntityPage/Q16355515'),
#    (3, 'https://ang.wikipedia.org/wiki/Help:Inno%C3%BE'),
#    (4, 'https://ceb.wikipedia.org/wiki/Tabang:Mga_sulod'),
#    (2, 'https://en.wikipedia.org/wiki/Deputy_mayor'),
#    (3, 'https://da.wikipedia.org/wiki/Hj%C3%A6lp:Mentorer'),
#    (5, 'https://als.wikipedia.org/wiki/Spezial:Myyni_Byytreeg'),
#    (1,
#     'https://ang.wikipedia.org/w/index.php?title=Syndrig:Book&bookcmd=book_creator&referer=Help%3AInno%C3%BE'),
#    (8,
#     'https://sw.wikipedia.org/wiki/Majadiliano_ya_Wikipedia:Msaada_wa_kuanzisha_makala'),
#    (1, 'https://en.wikipedia.org/wiki/Chamoy'),
#    (2, 'https://da.wikipedia.org/wiki/Wayback_Machine')],
#   'frequency': 65,
#   'idf': 2.966857852454854},
#  'summari': {'postings': [(6, 'https://bagerbach.com/books/the-go-giver'),
#    (15, 'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it'),
#    (9, 'https://bagerbach.com/books/a-brief-history-of-time'),
#    (10, 'https://bagerbach.com/books/the-richest-man-in-babylon'),
#    (7, 'https://bagerbach.com/books/the-personal-mba'),
#    (10, 'https://bagerbach.com/books/reality-is-not-what-it-seems'),
#    (7, 'https://bagerbach.com/books/leaders-eat-last'),
#    (7, 'https://bagerbach.com/books/anything-you-want')],
#   'frequency': 8,
#   'idf': 5.061803580670655},
#  '&': {'postings': [(7, 'https://bagerbach.com/books/the-go-giver'),
#    (16, 'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it'),
#    (10, 'https://bagerbach.com/books/a-brief-history-of-time'),
#    (11, 'https://bagerbach.com/books/the-richest-man-in-babylon'),
#    (8, 'https://bagerbach.com/books/the-personal-mba'),
#    (11, 'https://bagerbach.com/books/reality-is-not-what-it-seems'),
#    (8, 'https://bagerbach.com/books/leaders-eat-last'),
#    (8, 'https://bagerbach.com/books/anything-you-want')],
#   'frequency': 8,
#   'idf': 5.061803580670655},
#  'antifragil': {'postings': [(0,
#     'https://www.wikiwand.com/en/Antifragile#/Barbell_strategy'),
#    (5,
#     'https://en.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0'),
#    (5,
#     'https://en.m.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0&mobileaction=toggle_view_mobile'),
#    (5, 'https://en.wikipedia.org/wiki/Special:WhatLinksHere/Antifragile'),
#    (3,
#     'https://en.wikipedia.org/w/index.php?title=Talk:Antifragile&action=edit'),
#    (5,
#     'https://en.m.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0&limit=100'),
#    (1,
#     'https://en.m.wikipedia.org/w/index.php?title=Antifragile_(disambiguation)&action=edit'),
#    (0, 'https://notes.bagerbach.com/antifragile')],
#   'frequency': 8,
#   'idf': 5.061803580670655},
#  'wikiwand': {'postings': [(2,
#     'https://www.wikiwand.com/en/Antifragile#/Barbell_strategy'),
#    (3, 'https://www.wikiwand.com/privacy'),
#    (0, 'https://www.wikiwand.com/contact'),
#    (0,
#     'https://chrome.google.com/webstore/detail/wikiwand-wikipedia-modern/emffkefkbkpkgpdeeooapgaicgmcbolj'),
#    (0, 'https://www.wikiwand.com/'),
#    (0, 'https://www.wikiwand.com/press'),
#    (2, 'https://techcrunch.com/2014/08/07/wikiwand/'),
#    (2, 'https://www.thefwa.com/interview/team-at-wikiwand/'),
#    (5, 'https://www.wikiwand.com/en/File:Disambig_gray.svg'),
#    (0, 'https://www.facebook.com/wikiwandapp'),
#    (4, 'https://www.wikiwand.com/en/Scalable_Vector_Graphics')],
#   'frequency': 11,
#   'idf': 4.7433498495521205},
#  'whi': {'postings': [(0,
#     'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'we': {'postings': [(1,
#     'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'get': {'postings': [(2,
#     'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it'),
#    (2,
#     'https://notes.bagerbach.com/minimize-time-getting-into-position-just-go')],
#   'frequency': 2,
#   'idf': 6.448097941790546},
#  'fat': {'postings': [(3,
#     'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  ':': {'postings': [(4,
#     'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it'),
#    (1,
#     'https://chrome.google.com/webstore/detail/wikiwand-wikipedia-modern/emffkefkbkpkgpdeeooapgaicgmcbolj'),
#    (2,
#     'https://en.wikipedia.org/w/index.php?title=Talk:Antifragile&action=edit'),
#    (1,
#     'https://en.wikipedia.org/wiki/Wikipedia:Disambiguation_pages_with_links'),
#    (1, 'https://www.wikiwand.com/en/File:Disambig_gray.svg'),
#    (1,
#     'https://da.wikipedia.org/wiki/Wikipedia:Artikler_med_flertydige_titler_som_der_henvises_til'),
#    (1, 'https://en.wikipedia.org/wiki/File:Red_star2.png'),
#    (1, 'https://en.wikipedia.org/wiki/File:Rotating_red_star.gif'),
#    (1,
#     'https://lv.wikipedia.org/wiki/Vikiprojekts:Vikip%C4%93dijas_uzlabo%C5%A1ana/Noz%C4%ABmju_atdal%C4%AB%C5%A1ana/Noz%C4%ABmju_atdal%C4%AB%C5%A1anas_lapas_ar_sait%C4%93m'),
#    (1, 'https://da.wikipedia.org/wiki/Hj%C3%A6lp:Forside'),
#    (2, 'https://en.wikipedia.org/wiki/User_talk:Vegaswikian'),
#    (1, 'https://min.wikipedia.org/wiki/Bantuan:Isi'),
#    (1,
#     'https://en.wikipedia.org/wiki/Wikipedia:Disambiguation_pages_with_links/February_2019'),
#    (1,
#     'https://kk.wikipedia.org/wiki/%D0%A3%D0%B8%D0%BA%D0%B8%D0%BF%D0%B5%D0%B4%D0%B8%D1%8F:%D0%90%D0%BD%D1%8B%D2%9B%D1%82%D0%B0%D0%BC%D0%B0'),
#    (1, 'https://bi.wikipedia.org/wiki/Help:Contents'),
#    (1,
#     'https://km.wikipedia.org/wiki/%E1%9E%87%E1%9F%86%E1%9E%93%E1%9E%BD%E1%9E%99:%E1%9E%98%E1%9E%B6%E1%9E%8F%E1%9E%B7%E1%9E%80%E1%9E%B6'),
#    (4,
#     'https://en.m.wikipedia.org/w/index.php?title=Module:Yesno&action=edit'),
#    (1, 'https://bat-smg.wikipedia.org/wiki/Pagelba:Tor%C4%97n%C4%ABs'),
#    (1, 'https://als.wikipedia.org/wiki/Wikipedia:Hilfe'),
#    (1, 'https://sw.wikipedia.org/wiki/Wikipedia:Msaada_wa_kuanzisha_makala'),
#    (1,
#     'https://mn.wikipedia.org/wiki/%D0%A2%D1%83%D1%81%D0%BB%D0%B0%D0%BC%D0%B6:%D0%90%D0%B3%D1%83%D1%83%D0%BB%D0%B3%D0%B0'),
#    (1, 'https://en.m.wikipedia.org/wiki/Module:Category_handler/blacklist'),
#    (1,
#     'https://kn.wikipedia.org/wiki/%E0%B2%B8%E0%B2%B9%E0%B2%BE%E0%B2%AF:%E0%B2%AA%E0%B2%B0%E0%B2%BF%E0%B2%B5%E0%B2%BF%E0%B2%A1%E0%B2%BF'),
#    (1,
#     'https://commons.wikimedia.org/wiki/Template:Vector_version_available/sco'),
#    (1, 'https://ang.wikipedia.org/wiki/Help:Inno%C3%BE'),
#    (2,
#     'https://kk.wikipedia.org/w/index.php?title=%D0%A3%D0%B8%D0%BA%D0%B8%D0%BF%D0%B5%D0%B4%D0%B8%D1%8F:%D0%90%D0%BD%D1%8B%D2%9B%D1%82%D0%B0%D0%BC%D0%B0&action=info'),
#    (1, 'https://ceb.wikipedia.org/wiki/Tabang:Mga_sulod'),
#    (1, 'https://da.wikipedia.org/wiki/Hj%C3%A6lp:Mentorer'),
#    (1,
#     'https://tt.wikipedia.org/wiki/%D0%92%D0%B8%D0%BA%D0%B8%D0%BF%D0%B5%D0%B4%D0%B8%D1%8F:%D0%AF%D1%80%D0%B4%D3%99%D0%BC'),
#    (3,
#     'https://sw.wikipedia.org/wiki/Majadiliano_ya_Wikipedia:Msaada_wa_kuanzisha_makala')],
#   'frequency': 30,
#   'idf': 3.7400477406883357},
#  'and': {'postings': [(5,
#     'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it'),
#    (5, 'https://notes.bagerbach.com/pp-6-declaring-types-and-type-classes'),
#    (1, 'https://developer.wikimedia.org'),
#    (2,
#     'https://web.archive.org/web/20030401130935/http://topology.org/comms/radcodes.html')],
#   'frequency': 4,
#   'idf': 5.7549507612306},
#  'what': {'postings': [(6,
#     'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it'),
#    (3, 'https://bagerbach.com/books/reality-is-not-what-it-seems')],
#   'frequency': 2,
#   'idf': 6.448097941790546},
#  'to': {'postings': [(7,
#     'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it'),
#    (3,
#     'https://en.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0'),
#    (3,
#     'https://en.m.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0&mobileaction=toggle_view_mobile'),
#    (3, 'https://en.wikipedia.org/wiki/Special:WhatLinksHere/Antifragile'),
#    (3,
#     'https://notes.bagerbach.com/increase-your-leverage-to-become-more-productive'),
#    (6, 'https://techcrunch.com/2014/08/07/wikiwand/'),
#    (3,
#     'https://en.m.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0&limit=100')],
#   'frequency': 7,
#   'idf': 5.195334973295178},
#  'do': {'postings': [(8,
#     'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'about': {'postings': [(9,
#     'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'it': {'postings': [(10,
#     'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it'),
#    (4, 'https://bagerbach.com/books/reality-is-not-what-it-seems')],
#   'frequency': 2,
#   'idf': 6.448097941790546},
#  'gari': {'postings': [(12,
#     'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'taub': {'postings': [(13,
#     'https://bagerbach.com/books/why-we-get-fat-and-what-to-do-about-it')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'pp': {'postings': [(0,
#     'https://notes.bagerbach.com/pp-6-declaring-types-and-type-classes')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  '6': {'postings': [(1,
#     'https://notes.bagerbach.com/pp-6-declaring-types-and-type-classes')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'declar': {'postings': [(3,
#     'https://notes.bagerbach.com/pp-6-declaring-types-and-type-classes')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'type': {'postings': [(4,
#     'https://notes.bagerbach.com/pp-6-declaring-types-and-type-classes'),
#    (6, 'https://notes.bagerbach.com/pp-6-declaring-types-and-type-classes')],
#   'frequency': 2,
#   'idf': 6.448097941790546},
#  'class': {'postings': [(7,
#     'https://notes.bagerbach.com/pp-6-declaring-types-and-type-classes')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'privaci': {'postings': [(0, 'https://www.wikiwand.com/privacy')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'polici': {'postings': [(1, 'https://www.wikiwand.com/privacy')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'page': {'postings': [(0,
#     'https://en.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0'),
#    (0,
#     'https://en.m.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0&mobileaction=toggle_view_mobile'),
#    (0, 'https://en.wikipedia.org/wiki/Special:WhatLinksHere/Antifragile'),
#    (3,
#     'https://en.wikipedia.org/wiki/Wikipedia:Disambiguation_pages_with_links'),
#    (0,
#     'https://en.m.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0&limit=100'),
#    (3,
#     'https://en.wikipedia.org/wiki/Wikipedia:Disambiguation_pages_with_links/February_2019')],
#   'frequency': 6,
#   'idf': 5.349485653122436},
#  'that': {'postings': [(1,
#     'https://en.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0'),
#    (1,
#     'https://en.m.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0&mobileaction=toggle_view_mobile'),
#    (1, 'https://en.wikipedia.org/wiki/Special:WhatLinksHere/Antifragile'),
#    (1,
#     'https://en.m.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0&limit=100')],
#   'frequency': 4,
#   'idf': 5.7549507612306},
#  'link': {'postings': [(2,
#     'https://en.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0'),
#    (2,
#     'https://en.m.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0&mobileaction=toggle_view_mobile'),
#    (2, 'https://en.wikipedia.org/wiki/Special:WhatLinksHere/Antifragile'),
#    (5,
#     'https://en.wikipedia.org/wiki/Wikipedia:Disambiguation_pages_with_links'),
#    (2,
#     'https://en.m.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0&limit=100')],
#   'frequency': 5,
#   'idf': 5.531807209916391},
#  '``': {'postings': [(4,
#     'https://en.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0'),
#    (4,
#     'https://en.m.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0&mobileaction=toggle_view_mobile'),
#    (4, 'https://en.wikipedia.org/wiki/Special:WhatLinksHere/Antifragile'),
#    (4,
#     'https://en.m.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0&limit=100'),
#    (4, 'https://da.wikipedia.org/wiki/Speciel:Hvad_linker_hertil/B%C3%A5nd'),
#    (4,
#     'https://da.wikipedia.org/w/index.php?title=Speciel:Hvad_linker_hertil/B%C3%A5nd&limit=500')],
#   'frequency': 6,
#   'idf': 5.349485653122436},
#  "''": {'postings': [(6,
#     'https://en.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0'),
#    (6,
#     'https://en.m.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0&mobileaction=toggle_view_mobile'),
#    (6, 'https://en.wikipedia.org/wiki/Special:WhatLinksHere/Antifragile'),
#    (6,
#     'https://en.m.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0&limit=100'),
#    (6, 'https://da.wikipedia.org/wiki/Speciel:Hvad_linker_hertil/B%C3%A5nd'),
#    (6,
#     'https://da.wikipedia.org/w/index.php?title=Speciel:Hvad_linker_hertil/B%C3%A5nd&limit=500')],
#   'frequency': 6,
#   'idf': 5.349485653122436},
#  'wikipedia': {'postings': [(8,
#     'https://en.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0'),
#    (8,
#     'https://en.m.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0&mobileaction=toggle_view_mobile'),
#    (8, 'https://en.wikipedia.org/wiki/Special:WhatLinksHere/Antifragile'),
#    (2,
#     'https://chrome.google.com/webstore/detail/wikiwand-wikipedia-modern/emffkefkbkpkgpdeeooapgaicgmcbolj'),
#    (5,
#     'https://en.wikipedia.org/w/index.php?title=Talk:Antifragile&action=edit'),
#    (8, 'https://techcrunch.com/2014/08/07/wikiwand/'),
#    (0,
#     'https://en.wikipedia.org/wiki/Wikipedia:Disambiguation_pages_with_links'),
#    (7,
#     'https://en.wikipedia.org/wiki/Wikipedia:Disambiguation_pages_with_links'),
#    (8,
#     'https://en.m.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Antifragile&namespace=0&limit=100'),
#    (0,
#     'https://da.wikipedia.org/wiki/Wikipedia:Artikler_med_flertydige_titler_som_der_henvises_til'),
#    (11,
#     'https://da.wikipedia.org/wiki/Wikipedia:Artikler_med_flertydige_titler_som_der_henvises_til'),
#    (5, 'https://en.wikipedia.org/wiki/File:Red_star2.png'),
#    (8, 'https://da.wikipedia.org/wiki/Speciel:Hvad_linker_hertil/B%C3%A5nd'),
#    (6, 'https://en.wikipedia.org/wiki/File:Rotating_red_star.gif'),
#    (3, 'https://en.wikipedia.org/wiki/Lee_Jenkins'),
#    (4, 'https://da.wikipedia.org/wiki/Hj%C3%A6lp:Forside'),
#    (4,
#     'https://en.m.wikipedia.org/w/index.php?title=Alan_Blinder&action=edit'),
#    (5, 'https://en.wikipedia.org/wiki/User_talk:Vegaswikian'),
#    (2, 'https://da.wikipedia.org/wiki/Frekvensb%C3%A5nd'),
#    (4, 'https://min.wikipedia.org/wiki/Bantuan:Isi'),
#    (6,
#     'https://en.m.wikipedia.org/w/index.php?title=Antifragile_(disambiguation)&action=edit'),
#    (0,
#     'https://en.wikipedia.org/wiki/Wikipedia:Disambiguation_pages_with_links/February_2019'),
#    (8,
#     'https://en.wikipedia.org/wiki/Wikipedia:Disambiguation_pages_with_links/February_2019'),
#    (8,
#     'https://da.wikipedia.org/w/index.php?title=Speciel:Hvad_linker_hertil/B%C3%A5nd&limit=500'),
#    (4, 'https://bi.wikipedia.org/wiki/Help:Contents'),
#    (2, 'https://en.wikipedia.org/wiki/Anuradha'),
#    (7,
#     'https://en.m.wikipedia.org/w/index.php?title=Module:Yesno&action=edit'),
#    (3, 'https://da.wikipedia.org/wiki/Speciel:For%C3%A6ldrel%C3%B8se_sider'),
#    (4, 'https://bat-smg.wikipedia.org/wiki/Pagelba:Tor%C4%97n%C4%ABs'),
#    (3, 'https://en.wikipedia.org/wiki/Charles_Taylor'),
#    (0, 'https://als.wikipedia.org/wiki/Wikipedia:Hilfe'),
#    (5, 'https://als.wikipedia.org/wiki/Wikipedia:Hilfe'),
#    (0, 'https://sw.wikipedia.org/wiki/Wikipedia:Msaada_wa_kuanzisha_makala'),
#    (7, 'https://sw.wikipedia.org/wiki/Wikipedia:Msaada_wa_kuanzisha_makala'),
#    (5, 'https://da.wikipedia.org/wiki/Virkning_(flertydig)'),
#    (2, 'https://en.wikipedia.org/wiki/Deputy'),
#    (5, 'https://en.m.wikipedia.org/wiki/Module:Category_handler/blacklist'),
#    (2, 'https://en.wikipedia.org/wiki/CSO'),
#    (2, 'https://da.wikipedia.org/wiki/Kup'),
#    (5, 'https://ceb.wikipedia.org/wiki/Tabang:Mga_sulod'),
#    (3, 'https://en.wikipedia.org/wiki/Deputy_mayor'),
#    (4, 'https://da.wikipedia.org/wiki/Hj%C3%A6lp:Mentorer'),
#    (4,
#     'https://tt.wikipedia.org/wiki/%D0%92%D0%B8%D0%BA%D0%B8%D0%BF%D0%B5%D0%B4%D0%B8%D1%8F:%D0%AF%D1%80%D0%B4%D3%99%D0%BC'),
#    (7, 'https://als.wikipedia.org/wiki/Spezial:Myyni_Byytreeg'),
#    (2,
#     'https://sw.wikipedia.org/wiki/Majadiliano_ya_Wikipedia:Msaada_wa_kuanzisha_makala'),
#    (9,
#     'https://sw.wikipedia.org/wiki/Majadiliano_ya_Wikipedia:Msaada_wa_kuanzisha_makala'),
#    (2, 'https://en.wikipedia.org/wiki/Chamoy'),
#    (3, 'https://da.wikipedia.org/wiki/Wayback_Machine')],
#   'frequency': 48,
#   'idf': 3.2700441114426},
#  'a': {'postings': [(0, 'https://bagerbach.com/books/a-brief-history-of-time'),
#    (9, 'https://techcrunch.com/2014/08/07/wikiwand/')],
#   'frequency': 2,
#   'idf': 6.448097941790546},
#  'brief': {'postings': [(1,
#     'https://bagerbach.com/books/a-brief-history-of-time')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'histori': {'postings': [(2,
#     'https://bagerbach.com/books/a-brief-history-of-time')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'of': {'postings': [(3,
#     'https://bagerbach.com/books/a-brief-history-of-time'),
#    (2, 'https://notes.bagerbach.com/the-law-of-inertia')],
#   'frequency': 2,
#   'idf': 6.448097941790546},
#  'time': {'postings': [(4,
#     'https://bagerbach.com/books/a-brief-history-of-time'),
#    (1,
#     'https://notes.bagerbach.com/minimize-time-getting-into-position-just-go')],
#   'frequency': 2,
#   'idf': 6.448097941790546},
#  'stephen': {'postings': [(6,
#     'https://bagerbach.com/books/a-brief-history-of-time')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'hawk': {'postings': [(7,
#     'https://bagerbach.com/books/a-brief-history-of-time')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'innov': {'postings': [(0,
#     'https://notes.bagerbach.com/innovation-multiplier')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'multipli': {'postings': [(1,
#     'https://notes.bagerbach.com/innovation-multiplier')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'contact': {'postings': [(2, 'https://www.wikiwand.com/contact')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'us': {'postings': [(3, 'https://www.wikiwand.com/contact')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'modern': {'postings': [(3,
#     'https://chrome.google.com/webstore/detail/wikiwand-wikipedia-modern/emffkefkbkpkgpdeeooapgaicgmcbolj')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'chrome': {'postings': [(5,
#     'https://chrome.google.com/webstore/detail/wikiwand-wikipedia-modern/emffkefkbkpkgpdeeooapgaicgmcbolj')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'webshop': {'postings': [(6,
#     'https://chrome.google.com/webstore/detail/wikiwand-wikipedia-modern/emffkefkbkpkgpdeeooapgaicgmcbolj')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'jarry1250': {'postings': [(0,
#     'https://templatecount.toolforge.org/index.php?lang=en&namespace=0&name=Antifragile')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'wikimedia': {'postings': [(2,
#     'https://templatecount.toolforge.org/index.php?lang=en&namespace=0&name=Antifragile'),
#    (3, 'https://developer.wikimedia.org'),
#    (6, 'https://developer.wikimedia.org'),
#    (0, 'https://wikimediafoundation.org/'),
#    (6,
#     'https://commons.wikimedia.org/wiki/Template:Vector_version_available/sco')],
#   'frequency': 5,
#   'idf': 5.531807209916391},
#  'laboratori': {'postings': [(3,
#     'https://templatecount.toolforge.org/index.php?lang=en&namespace=0&name=Antifragile')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'templat': {'postings': [(5,
#     'https://templatecount.toolforge.org/index.php?lang=en&namespace=0&name=Antifragile'),
#    (0,
#     'https://commons.wikimedia.org/wiki/Template:Vector_version_available/sco')],
#   'frequency': 2,
#   'idf': 6.448097941790546},
#  'transclus': {'postings': [(6,
#     'https://templatecount.toolforge.org/index.php?lang=en&namespace=0&name=Antifragile')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'count': {'postings': [(7,
#     'https://templatecount.toolforge.org/index.php?lang=en&namespace=0&name=Antifragile')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'increas': {'postings': [(0,
#     'https://notes.bagerbach.com/increase-your-leverage-to-become-more-productive')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'your': {'postings': [(1,
#     'https://notes.bagerbach.com/increase-your-leverage-to-become-more-productive')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'leverag': {'postings': [(2,
#     'https://notes.bagerbach.com/increase-your-leverage-to-become-more-productive')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'becom': {'postings': [(4,
#     'https://notes.bagerbach.com/increase-your-leverage-to-become-more-productive')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'more': {'postings': [(5,
#     'https://notes.bagerbach.com/increase-your-leverage-to-become-more-productive')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'product': {'postings': [(6,
#     'https://notes.bagerbach.com/increase-your-leverage-to-become-more-productive')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'richest': {'postings': [(1,
#     'https://bagerbach.com/books/the-richest-man-in-babylon')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'man': {'postings': [(2,
#     'https://bagerbach.com/books/the-richest-man-in-babylon')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'in': {'postings': [(3,
#     'https://bagerbach.com/books/the-richest-man-in-babylon')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'babylon': {'postings': [(4,
#     'https://bagerbach.com/books/the-richest-man-in-babylon')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'georg': {'postings': [(6,
#     'https://bagerbach.com/books/the-richest-man-in-babylon')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  's.': {'postings': [(7,
#     'https://bagerbach.com/books/the-richest-man-in-babylon')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'clason': {'postings': [(8,
#     'https://bagerbach.com/books/the-richest-man-in-babylon')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'edit': {'postings': [(0,
#     'https://en.wikipedia.org/w/index.php?title=Talk:Antifragile&action=edit'),
#    (0,
#     'https://en.m.wikipedia.org/w/index.php?title=Alan_Blinder&action=edit'),
#    (0,
#     'https://en.m.wikipedia.org/w/index.php?title=Antifragile_(disambiguation)&action=edit')],
#   'frequency': 3,
#   'idf': 6.042632833682381},
#  'talk': {'postings': [(1,
#     'https://en.wikipedia.org/w/index.php?title=Talk:Antifragile&action=edit'),
#    (1, 'https://en.wikipedia.org/wiki/User_talk:Vegaswikian')],
#   'frequency': 2,
#   'idf': 6.448097941790546},
#  'discov': {'postings': [(0, 'https://developer.wikimedia.org')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'build': {'postings': [(2, 'https://developer.wikimedia.org')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'technolog': {'postings': [(4, 'https://developer.wikimedia.org')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'develop': {'postings': [(7, 'https://developer.wikimedia.org')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'portal': {'postings': [(8, 'https://developer.wikimedia.org')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'zero': {'postings': [(0, 'https://notes.bagerbach.com/zero-sum')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'sum': {'postings': [(1, 'https://notes.bagerbach.com/zero-sum')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'press': {'postings': [(2, 'https://www.wikiwand.com/press')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'web': {'postings': [(0, 'https://techcrunch.com/2014/08/07/wikiwand/')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'app': {'postings': [(1, 'https://techcrunch.com/2014/08/07/wikiwand/')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'rais': {'postings': [(3, 'https://techcrunch.com/2014/08/07/wikiwand/')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  '$': {'postings': [(4, 'https://techcrunch.com/2014/08/07/wikiwand/')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  '600,000': {'postings': [(5, 'https://techcrunch.com/2014/08/07/wikiwand/')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'give': {'postings': [(7, 'https://techcrunch.com/2014/08/07/wikiwand/')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'new': {'postings': [(10, 'https://techcrunch.com/2014/08/07/wikiwand/')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'interfac': {'postings': [(11,
#     'https://techcrunch.com/2014/08/07/wikiwand/')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  '•': {'postings': [(12, 'https://techcrunch.com/2014/08/07/wikiwand/')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'techcrunch': {'postings': [(13,
#     'https://techcrunch.com/2014/08/07/wikiwand/')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'team': {'postings': [(0,
#     'https://www.thefwa.com/interview/team-at-wikiwand/')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'at': {'postings': [(1,
#     'https://www.thefwa.com/interview/team-at-wikiwand/')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'fwa': {'postings': [(5,
#     'https://www.thefwa.com/interview/team-at-wikiwand/')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'gall': {'postings': [(0, 'https://notes.bagerbach.com/gall-s-law')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'law': {'postings': [(2, 'https://notes.bagerbach.com/gall-s-law'),
#    (1, 'https://notes.bagerbach.com/the-law-of-inertia')],
#   'frequency': 2,
#   'idf': 6.448097941790546},
#  'disambigu': {'postings': [(2,
#     'https://en.wikipedia.org/wiki/Wikipedia:Disambiguation_pages_with_links'),
#    (3,
#     'https://en.m.wikipedia.org/w/index.php?title=Antifragile_(disambiguation)&action=edit'),
#    (2,
#     'https://en.wikipedia.org/wiki/Wikipedia:Disambiguation_pages_with_links/February_2019')],
#   'frequency': 3,
#   'idf': 6.042632833682381},
#  'with': {'postings': [(4,
#     'https://en.wikipedia.org/wiki/Wikipedia:Disambiguation_pages_with_links'),
#    (4,
#     'https://en.wikipedia.org/wiki/Wikipedia:Disambiguation_pages_with_links/February_2019')],
#   'frequency': 2,
#   'idf': 6.448097941790546},
#  'file': {'postings': [(0,
#     'https://www.wikiwand.com/en/File:Disambig_gray.svg'),
#    (0, 'https://en.wikipedia.org/wiki/File:Red_star2.png'),
#    (0, 'https://en.wikipedia.org/wiki/File:Rotating_red_star.gif')],
#   'frequency': 3,
#   'idf': 6.042632833682381},
#  'disambig': {'postings': [(2,
#     'https://www.wikiwand.com/en/File:Disambig_gray.svg')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'gray.svg': {'postings': [(3,
#     'https://www.wikiwand.com/en/File:Disambig_gray.svg')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'minim': {'postings': [(0,
#     'https://notes.bagerbach.com/minimize-time-getting-into-position-just-go')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'into': {'postings': [(3,
#     'https://notes.bagerbach.com/minimize-time-getting-into-position-just-go')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'posit': {'postings': [(4,
#     'https://notes.bagerbach.com/minimize-time-getting-into-position-just-go')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  ',': {'postings': [(5,
#     'https://notes.bagerbach.com/minimize-time-getting-into-position-just-go'),
#    (12,
#     'https://da.wikipedia.org/wiki/Wikipedia:Artikler_med_flertydige_titler_som_der_henvises_til'),
#    (9, 'https://da.wikipedia.org/wiki/Speciel:Hvad_linker_hertil/B%C3%A5nd'),
#    (5, 'https://da.wikipedia.org/wiki/Hj%C3%A6lp:Forside'),
#    (3, 'https://da.wikipedia.org/wiki/Frekvensb%C3%A5nd'),
#    (9,
#     'https://da.wikipedia.org/w/index.php?title=Speciel:Hvad_linker_hertil/B%C3%A5nd&limit=500'),
#    (4, 'https://da.wikipedia.org/wiki/Speciel:For%C3%A6ldrel%C3%B8se_sider'),
#    (8, 'https://sw.wikipedia.org/wiki/Wikipedia:Msaada_wa_kuanzisha_makala'),
#    (6, 'https://da.wikipedia.org/wiki/Virkning_(flertydig)'),
#    (3, 'https://da.wikipedia.org/wiki/Kup'),
#    (5, 'https://ang.wikipedia.org/wiki/Help:Inno%C3%BE'),
#    (5, 'https://da.wikipedia.org/wiki/Hj%C3%A6lp:Mentorer'),
#    (3,
#     'https://ang.wikipedia.org/w/index.php?title=Syndrig:Book&bookcmd=book_creator&referer=Help%3AInno%C3%BE'),
#    (10,
#     'https://sw.wikipedia.org/wiki/Majadiliano_ya_Wikipedia:Msaada_wa_kuanzisha_makala'),
#    (4, 'https://da.wikipedia.org/wiki/Wayback_Machine')],
#   'frequency': 15,
#   'idf': 4.4331949212482815},
#  'just': {'postings': [(6,
#     'https://notes.bagerbach.com/minimize-time-getting-into-position-just-go')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'go': {'postings': [(7,
#     'https://notes.bagerbach.com/minimize-time-getting-into-position-just-go')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'artikl': {'postings': [(2,
#     'https://da.wikipedia.org/wiki/Wikipedia:Artikler_med_flertydige_titler_som_der_henvises_til')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'med': {'postings': [(3,
#     'https://da.wikipedia.org/wiki/Wikipedia:Artikler_med_flertydige_titler_som_der_henvises_til')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'flertydig': {'postings': [(4,
#     'https://da.wikipedia.org/wiki/Wikipedia:Artikler_med_flertydige_titler_som_der_henvises_til'),
#    (2, 'https://da.wikipedia.org/wiki/Virkning_(flertydig)')],
#   'frequency': 2,
#   'idf': 6.448097941790546},
#  'titler': {'postings': [(5,
#     'https://da.wikipedia.org/wiki/Wikipedia:Artikler_med_flertydige_titler_som_der_henvises_til')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'som': {'postings': [(6,
#     'https://da.wikipedia.org/wiki/Wikipedia:Artikler_med_flertydige_titler_som_der_henvises_til')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'der': {'postings': [(7,
#     'https://da.wikipedia.org/wiki/Wikipedia:Artikler_med_flertydige_titler_som_der_henvises_til'),
#    (1, 'https://da.wikipedia.org/wiki/Speciel:Hvad_linker_hertil/B%C3%A5nd'),
#    (1,
#     'https://da.wikipedia.org/w/index.php?title=Speciel:Hvad_linker_hertil/B%C3%A5nd&limit=500')],
#   'frequency': 3,
#   'idf': 6.042632833682381},
#  'henvis': {'postings': [(8,
#     'https://da.wikipedia.org/wiki/Wikipedia:Artikler_med_flertydige_titler_som_der_henvises_til')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'til': {'postings': [(9,
#     'https://da.wikipedia.org/wiki/Wikipedia:Artikler_med_flertydige_titler_som_der_henvises_til'),
#    (3, 'https://da.wikipedia.org/wiki/Speciel:Hvad_linker_hertil/B%C3%A5nd'),
#    (3,
#     'https://da.wikipedia.org/w/index.php?title=Speciel:Hvad_linker_hertil/B%C3%A5nd&limit=500')],
#   'frequency': 3,
#   'idf': 6.042632833682381},
#  'den': {'postings': [(13,
#     'https://da.wikipedia.org/wiki/Wikipedia:Artikler_med_flertydige_titler_som_der_henvises_til'),
#    (10, 'https://da.wikipedia.org/wiki/Speciel:Hvad_linker_hertil/B%C3%A5nd'),
#    (6, 'https://da.wikipedia.org/wiki/Hj%C3%A6lp:Forside'),
#    (4, 'https://da.wikipedia.org/wiki/Frekvensb%C3%A5nd'),
#    (10,
#     'https://da.wikipedia.org/w/index.php?title=Speciel:Hvad_linker_hertil/B%C3%A5nd&limit=500'),
#    (5, 'https://da.wikipedia.org/wiki/Speciel:For%C3%A6ldrel%C3%B8se_sider'),
#    (7, 'https://da.wikipedia.org/wiki/Virkning_(flertydig)'),
#    (4, 'https://da.wikipedia.org/wiki/Kup'),
#    (6, 'https://da.wikipedia.org/wiki/Hj%C3%A6lp:Mentorer'),
#    (5, 'https://da.wikipedia.org/wiki/Wayback_Machine')],
#   'frequency': 10,
#   'idf': 4.838660029356445},
#  'frie': {'postings': [(14,
#     'https://da.wikipedia.org/wiki/Wikipedia:Artikler_med_flertydige_titler_som_der_henvises_til'),
#    (11, 'https://da.wikipedia.org/wiki/Speciel:Hvad_linker_hertil/B%C3%A5nd'),
#    (7, 'https://da.wikipedia.org/wiki/Hj%C3%A6lp:Forside'),
#    (5, 'https://da.wikipedia.org/wiki/Frekvensb%C3%A5nd'),
#    (11,
#     'https://da.wikipedia.org/w/index.php?title=Speciel:Hvad_linker_hertil/B%C3%A5nd&limit=500'),
#    (6, 'https://da.wikipedia.org/wiki/Speciel:For%C3%A6ldrel%C3%B8se_sider'),
#    (8, 'https://da.wikipedia.org/wiki/Virkning_(flertydig)'),
#    (5, 'https://da.wikipedia.org/wiki/Kup'),
#    (7, 'https://da.wikipedia.org/wiki/Hj%C3%A6lp:Mentorer'),
#    (6, 'https://da.wikipedia.org/wiki/Wayback_Machine')],
#   'frequency': 10,
#   'idf': 4.838660029356445},
#  'encyklopædi': {'postings': [(15,
#     'https://da.wikipedia.org/wiki/Wikipedia:Artikler_med_flertydige_titler_som_der_henvises_til'),
#    (12, 'https://da.wikipedia.org/wiki/Speciel:Hvad_linker_hertil/B%C3%A5nd'),
#    (8, 'https://da.wikipedia.org/wiki/Hj%C3%A6lp:Forside'),
#    (6, 'https://da.wikipedia.org/wiki/Frekvensb%C3%A5nd'),
#    (12,
#     'https://da.wikipedia.org/w/index.php?title=Speciel:Hvad_linker_hertil/B%C3%A5nd&limit=500'),
#    (7, 'https://da.wikipedia.org/wiki/Speciel:For%C3%A6ldrel%C3%B8se_sider'),
#    (9, 'https://da.wikipedia.org/wiki/Virkning_(flertydig)'),
#    (6, 'https://da.wikipedia.org/wiki/Kup'),
#    (8, 'https://da.wikipedia.org/wiki/Hj%C3%A6lp:Mentorer'),
#    (7, 'https://da.wikipedia.org/wiki/Wayback_Machine')],
#   'frequency': 10,
#   'idf': 4.838660029356445},
#  'red': {'postings': [(2, 'https://en.wikipedia.org/wiki/File:Red_star2.png'),
#    (3, 'https://en.wikipedia.org/wiki/File:Rotating_red_star.gif')],
#   'frequency': 2,
#   'idf': 6.448097941790546},
#  'star2.png': {'postings': [(3,
#     'https://en.wikipedia.org/wiki/File:Red_star2.png')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'person': {'postings': [(1, 'https://bagerbach.com/books/the-personal-mba')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'mba': {'postings': [(2, 'https://bagerbach.com/books/the-personal-mba')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
# ...
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'radio': {'postings': [(0,
#     'https://web.archive.org/web/20030401130935/http://topology.org/comms/radcodes.html')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'code': {'postings': [(1,
#     'https://web.archive.org/web/20030401130935/http://topology.org/comms/radcodes.html')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'band': {'postings': [(3,
#     'https://web.archive.org/web/20030401130935/http://topology.org/comms/radcodes.html')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'anuradha': {'postings': [(0, 'https://en.wikipedia.org/wiki/Anuradha')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'herm': {'postings': [(0, 'https://lv.wikipedia.org/wiki/Hermes')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'view': {'postings': [(0,
#     'https://en.m.wikipedia.org/w/index.php?title=Module:Yesno&action=edit')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'sourc': {'postings': [(1,
#     'https://en.m.wikipedia.org/w/index.php?title=Module:Yesno&action=edit')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'for': {'postings': [(2,
#     'https://en.m.wikipedia.org/w/index.php?title=Module:Yesno&action=edit')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'modul': {'postings': [(3,
#     'https://en.m.wikipedia.org/w/index.php?title=Module:Yesno&action=edit'),
#    (0, 'https://en.m.wikipedia.org/wiki/Module:Category_handler/blacklist')],
#   'frequency': 2,
#   'idf': 6.448097941790546},
#  'yesno': {'postings': [(5,
#     'https://en.m.wikipedia.org/w/index.php?title=Module:Yesno&action=edit')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'inertia': {'postings': [(3,
#     'https://notes.bagerbach.com/the-law-of-inertia')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'forældreløs': {'postings': [(0,
#     'https://da.wikipedia.org/wiki/Speciel:For%C3%A6ldrel%C3%B8se_sider')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'pagelba': {'postings': [(0,
#     'https://bat-smg.wikipedia.org/wiki/Pagelba:Tor%C4%97n%C4%ABs')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'torėnī': {'postings': [(2,
#     'https://bat-smg.wikipedia.org/wiki/Pagelba:Tor%C4%97n%C4%ABs')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'leader': {'postings': [(0, 'https://bagerbach.com/books/leaders-eat-last')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'eat': {'postings': [(1, 'https://bagerbach.com/books/leaders-eat-last')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'last': {'postings': [(2, 'https://bagerbach.com/books/leaders-eat-last')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'simon': {'postings': [(4, 'https://bagerbach.com/books/leaders-eat-last')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'sinek': {'postings': [(5, 'https://bagerbach.com/books/leaders-eat-last')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'charl': {'postings': [(0, 'https://en.wikipedia.org/wiki/Charles_Taylor')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'taylor': {'postings': [(1, 'https://en.wikipedia.org/wiki/Charles_Taylor')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'maguir': {'postings': [(0, 'https://lv.wikipedia.org/wiki/Maguire')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'hilf': {'postings': [(2, 'https://als.wikipedia.org/wiki/Wikipedia:Hilfe')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'alemannisch': {'postings': [(4,
#     'https://als.wikipedia.org/wiki/Wikipedia:Hilfe'),
#    (6, 'https://als.wikipedia.org/wiki/Spezial:Myyni_Byytreeg')],
#   'frequency': 2,
#   'idf': 6.448097941790546},
#  'msaada': {'postings': [(2,
#     'https://sw.wikipedia.org/wiki/Wikipedia:Msaada_wa_kuanzisha_makala'),
#    (4,
#     'https://sw.wikipedia.org/wiki/Majadiliano_ya_Wikipedia:Msaada_wa_kuanzisha_makala')],
#   'frequency': 2,
#   'idf': 6.448097941790546},
#  'wa': {'postings': [(3,
#     'https://sw.wikipedia.org/wiki/Wikipedia:Msaada_wa_kuanzisha_makala'),
#    (5,
#     'https://sw.wikipedia.org/wiki/Majadiliano_ya_Wikipedia:Msaada_wa_kuanzisha_makala')],
#   'frequency': 2,
#   'idf': 6.448097941790546},
#  'kuanzisha': {'postings': [(4,
#     'https://sw.wikipedia.org/wiki/Wikipedia:Msaada_wa_kuanzisha_makala'),
#    (6,
#     'https://sw.wikipedia.org/wiki/Majadiliano_ya_Wikipedia:Msaada_wa_kuanzisha_makala')],
#   'frequency': 2,
#   'idf': 6.448097941790546},
#  'makala': {'postings': [(5,
#     'https://sw.wikipedia.org/wiki/Wikipedia:Msaada_wa_kuanzisha_makala'),
#    (7,
#     'https://sw.wikipedia.org/wiki/Majadiliano_ya_Wikipedia:Msaada_wa_kuanzisha_makala')],
#   'frequency': 2,
#   'idf': 6.448097941790546},
#  'kamusi': {'postings': [(9,
#     'https://sw.wikipedia.org/wiki/Wikipedia:Msaada_wa_kuanzisha_makala'),
#    (11,
#     'https://sw.wikipedia.org/wiki/Majadiliano_ya_Wikipedia:Msaada_wa_kuanzisha_makala')],
#   'frequency': 2,
#   'idf': 6.448097941790546},
#  'elezo': {'postings': [(10,
#     'https://sw.wikipedia.org/wiki/Wikipedia:Msaada_wa_kuanzisha_makala'),
#    (12,
#     'https://sw.wikipedia.org/wiki/Majadiliano_ya_Wikipedia:Msaada_wa_kuanzisha_makala')],
#   'frequency': 2,
#   'idf': 6.448097941790546},
#  'huru': {'postings': [(11,
#     'https://sw.wikipedia.org/wiki/Wikipedia:Msaada_wa_kuanzisha_makala'),
#    (13,
#     'https://sw.wikipedia.org/wiki/Majadiliano_ya_Wikipedia:Msaada_wa_kuanzisha_makala')],
#   'frequency': 2,
#   'idf': 6.448097941790546},
#  'тусламж': {'postings': [(0,
#     'https://mn.wikipedia.org/wiki/%D0%A2%D1%83%D1%81%D0%BB%D0%B0%D0%BC%D0%B6:%D0%90%D0%B3%D1%83%D1%83%D0%BB%D0%B3%D0%B0')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'агуулга': {'postings': [(2,
#     'https://mn.wikipedia.org/wiki/%D0%A2%D1%83%D1%81%D0%BB%D0%B0%D0%BC%D0%B6:%D0%90%D0%B3%D1%83%D1%83%D0%BB%D0%B3%D0%B0')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'википедиа': {'postings': [(4,
#     'https://mn.wikipedia.org/wiki/%D0%A2%D1%83%D1%81%D0%BB%D0%B0%D0%BC%D0%B6:%D0%90%D0%B3%D1%83%D1%83%D0%BB%D0%B3%D0%B0')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'нэвтэрхий': {'postings': [(5,
#     'https://mn.wikipedia.org/wiki/%D0%A2%D1%83%D1%81%D0%BB%D0%B0%D0%BC%D0%B6:%D0%90%D0%B3%D1%83%D1%83%D0%BB%D0%B3%D0%B0')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'толь': {'postings': [(6,
#     'https://mn.wikipedia.org/wiki/%D0%A2%D1%83%D1%81%D0%BB%D0%B0%D0%BC%D0%B6:%D0%90%D0%B3%D1%83%D1%83%D0%BB%D0%B3%D0%B0')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'virkn': {'postings': [(0,
#     'https://da.wikipedia.org/wiki/Virkning_(flertydig)')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'deputi': {'postings': [(0, 'https://en.wikipedia.org/wiki/Deputy'),
#    (0, 'https://en.wikipedia.org/wiki/Deputy_mayor')],
#   'frequency': 2,
#   'idf': 6.448097941790546},
#  'opportun': {'postings': [(0,
#     'https://notes.bagerbach.com/opportunity-cost')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'cost': {'postings': [(1, 'https://notes.bagerbach.com/opportunity-cost')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'dzērvīte': {'postings': [(0,
#     'https://lv.wikipedia.org/wiki/Dz%C4%93rv%C4%ABte')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'anyth': {'postings': [(0, 'https://bagerbach.com/books/anything-you-want')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'you': {'postings': [(1, 'https://bagerbach.com/books/anything-you-want')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'want': {'postings': [(2, 'https://bagerbach.com/books/anything-you-want')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'derek': {'postings': [(4, 'https://bagerbach.com/books/anything-you-want')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'siver': {'postings': [(5, 'https://bagerbach.com/books/anything-you-want')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'categori': {'postings': [(2,
#     'https://en.m.wikipedia.org/wiki/Module:Category_handler/blacklist')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'handler/blacklist': {'postings': [(3,
#     'https://en.m.wikipedia.org/wiki/Module:Category_handler/blacklist')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'ಸಹಾಯ': {'postings': [(0,
#     'https://kn.wikipedia.org/wiki/%E0%B2%B8%E0%B2%B9%E0%B2%BE%E0%B2%AF:%E0%B2%AA%E0%B2%B0%E0%B2%BF%E0%B2%B5%E0%B2%BF%E0%B2%A1%E0%B2%BF')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'ಪರಿವಿಡಿ': {'postings': [(2,
#     'https://kn.wikipedia.org/wiki/%E0%B2%B8%E0%B2%B9%E0%B2%BE%E0%B2%AF:%E0%B2%AA%E0%B2%B0%E0%B2%BF%E0%B2%B5%E0%B2%BF%E0%B2%A1%E0%B2%BF')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'ವಿಕಿಪೀಡಿಯ': {'postings': [(4,
#     'https://kn.wikipedia.org/wiki/%E0%B2%B8%E0%B2%B9%E0%B2%BE%E0%B2%AF:%E0%B2%AA%E0%B2%B0%E0%B2%BF%E0%B2%B5%E0%B2%BF%E0%B2%A1%E0%B2%BF')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'version': {'postings': [(3,
#     'https://commons.wikimedia.org/wiki/Template:Vector_version_available/sco')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'available/sco': {'postings': [(4,
#     'https://commons.wikimedia.org/wiki/Template:Vector_version_available/sco')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'common': {'postings': [(7,
#     'https://commons.wikimedia.org/wiki/Template:Vector_version_available/sco')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'cso': {'postings': [(0, 'https://en.wikipedia.org/wiki/CSO')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'tomēni': {'postings': [(0, 'https://lv.wikipedia.org/wiki/Tom%C4%93ni')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'kup': {'postings': [(0, 'https://da.wikipedia.org/wiki/Kup')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'wikidata': {'postings': [(2,
#     'https://www.wikidata.org/wiki/Special:EntityPage/Q16355515')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'innoþ': {'postings': [(2, 'https://ang.wikipedia.org/wiki/Help:Inno%C3%BE')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'wikipǣdia': {'postings': [(4,
#     'https://ang.wikipedia.org/wiki/Help:Inno%C3%BE'),
#    (2,
#     'https://ang.wikipedia.org/w/index.php?title=Syndrig:Book&bookcmd=book_creator&referer=Help%3AInno%C3%BE')],
#   'frequency': 2,
#   'idf': 6.448097941790546},
#  'sēo': {'postings': [(6, 'https://ang.wikipedia.org/wiki/Help:Inno%C3%BE'),
#    (4,
#     'https://ang.wikipedia.org/w/index.php?title=Syndrig:Book&bookcmd=book_creator&referer=Help%3AInno%C3%BE')],
#   'frequency': 2,
#   'idf': 6.448097941790546},
#  'frēo': {'postings': [(7, 'https://ang.wikipedia.org/wiki/Help:Inno%C3%BE'),
#    (5,
#     'https://ang.wikipedia.org/w/index.php?title=Syndrig:Book&bookcmd=book_creator&referer=Help%3AInno%C3%BE')],
#   'frequency': 2,
#   'idf': 6.448097941790546},
#  'wīsdōmbōc': {'postings': [(8,
#     'https://ang.wikipedia.org/wiki/Help:Inno%C3%BE'),
#    (6,
#     'https://ang.wikipedia.org/w/index.php?title=Syndrig:Book&bookcmd=book_creator&referer=Help%3AInno%C3%BE')],
#   'frequency': 2,
#   'idf': 6.448097941790546},
#  '«': {'postings': [(0,
#     'https://kk.wikipedia.org/w/index.php?title=%D0%A3%D0%B8%D0%BA%D0%B8%D0%BF%D0%B5%D0%B4%D0%B8%D1%8F:%D0%90%D0%BD%D1%8B%D2%9B%D1%82%D0%B0%D0%BC%D0%B0&action=info')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  '»': {'postings': [(4,
#     'https://kk.wikipedia.org/w/index.php?title=%D0%A3%D0%B8%D0%BA%D0%B8%D0%BF%D0%B5%D0%B4%D0%B8%D1%8F:%D0%90%D0%BD%D1%8B%D2%9B%D1%82%D0%B0%D0%BC%D0%B0&action=info')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'беті': {'postings': [(5,
#     'https://kk.wikipedia.org/w/index.php?title=%D0%A3%D0%B8%D0%BA%D0%B8%D0%BF%D0%B5%D0%B4%D0%B8%D1%8F:%D0%90%D0%BD%D1%8B%D2%9B%D1%82%D0%B0%D0%BC%D0%B0&action=info')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'туралы': {'postings': [(6,
#     'https://kk.wikipedia.org/w/index.php?title=%D0%A3%D0%B8%D0%BA%D0%B8%D0%BF%D0%B5%D0%B4%D0%B8%D1%8F:%D0%90%D0%BD%D1%8B%D2%9B%D1%82%D0%B0%D0%BC%D0%B0&action=info')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'мәлімет': {'postings': [(7,
#     'https://kk.wikipedia.org/w/index.php?title=%D0%A3%D0%B8%D0%BA%D0%B8%D0%BF%D0%B5%D0%B4%D0%B8%D1%8F:%D0%90%D0%BD%D1%8B%D2%9B%D1%82%D0%B0%D0%BC%D0%B0&action=info')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'kron': {'postings': [(0,
#     'https://lv.wikipedia.org/wiki/Krons_(noz%C4%ABmju_atdal%C4%AB%C5%A1ana)')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'nozīmju': {'postings': [(2,
#     'https://lv.wikipedia.org/wiki/Krons_(noz%C4%ABmju_atdal%C4%AB%C5%A1ana)')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'tabang': {'postings': [(0,
#     'https://ceb.wikipedia.org/wiki/Tabang:Mga_sulod')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'mga': {'postings': [(2, 'https://ceb.wikipedia.org/wiki/Tabang:Mga_sulod')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'sulod': {'postings': [(3,
#     'https://ceb.wikipedia.org/wiki/Tabang:Mga_sulod')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'mayor': {'postings': [(1, 'https://en.wikipedia.org/wiki/Deputy_mayor')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'super': {'postings': [(0, 'https://et.wikipedia.org/wiki/Super_League')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'leagu': {'postings': [(1, 'https://et.wikipedia.org/wiki/Super_League')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  '–': {'postings': [(2, 'https://et.wikipedia.org/wiki/Super_League')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'vikipeedia': {'postings': [(3,
#     'https://et.wikipedia.org/wiki/Super_League')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'mentor': {'postings': [(2,
#     'https://da.wikipedia.org/wiki/Hj%C3%A6lp:Mentorer')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'википедия': {'postings': [(0,
#     'https://tt.wikipedia.org/wiki/%D0%92%D0%B8%D0%BA%D0%B8%D0%BF%D0%B5%D0%B4%D0%B8%D1%8F:%D0%AF%D1%80%D0%B4%D3%99%D0%BC')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'ярдәм': {'postings': [(2,
#     'https://tt.wikipedia.org/wiki/%D0%92%D0%B8%D0%BA%D0%B8%D0%BF%D0%B5%D0%B4%D0%B8%D1%8F:%D0%AF%D1%80%D0%B4%D3%99%D0%BC')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'benutzerbyytreg': {'postings': [(0,
#     'https://als.wikipedia.org/wiki/Spezial:Myyni_Byytreeg')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'vu': {'postings': [(1,
#     'https://als.wikipedia.org/wiki/Spezial:Myyni_Byytreeg')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  '„': {'postings': [(2,
#     'https://als.wikipedia.org/wiki/Spezial:Myyni_Byytreeg')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  '212.112.150.36': {'postings': [(3,
#     'https://als.wikipedia.org/wiki/Spezial:Myyni_Byytreeg')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  '“': {'postings': [(4,
#     'https://als.wikipedia.org/wiki/Spezial:Myyni_Byytreeg')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'black': {'postings': [(0, 'https://notes.bagerbach.com/black-swan')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'swan': {'postings': [(1, 'https://notes.bagerbach.com/black-swan')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'stare': {'postings': [(0, 'https://lv.wikipedia.org/wiki/Stare_Mesto')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'mesto': {'postings': [(1, 'https://lv.wikipedia.org/wiki/Stare_Mesto')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'bocscyppend': {'postings': [(0,
#     'https://ang.wikipedia.org/w/index.php?title=Syndrig:Book&bookcmd=book_creator&referer=Help%3AInno%C3%BE')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'mediawiki': {'postings': [(0, 'https://www.mediawiki.org/')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'majadiliano': {'postings': [(0,
#     'https://sw.wikipedia.org/wiki/Majadiliano_ya_Wikipedia:Msaada_wa_kuanzisha_makala')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'ya': {'postings': [(1,
#     'https://sw.wikipedia.org/wiki/Majadiliano_ya_Wikipedia:Msaada_wa_kuanzisha_makala')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'chamoy': {'postings': [(0, 'https://en.wikipedia.org/wiki/Chamoy')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'wayback': {'postings': [(0,
#     'https://da.wikipedia.org/wiki/Wayback_Machine')],
#   'frequency': 1,
#   'idf': 7.141245122350491},
#  'machin': {'postings': [(1, 'https://da.wikipedia.org/wiki/Wayback_Machine')],
#   'frequency': 1,
#   'idf': 7.141245122350491}}
